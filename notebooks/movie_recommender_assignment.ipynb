# %% [markdown]
# ## 1 Installation of Surprise in Google Colab

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading https://files.pythonhosted.org/packages/61/de/e5cba8682201fcf9c3719a6fdda95693468ed061945493dea2dd37c5618b/surprise-0.1-py2.py3-none-any.whl
# Collecting scikit-surprise
#   Downloading https://files.pythonhosted.org/packages/97/37/5d334adaf5ddd65da99fc65f6507e0e4599d092ba048f4302fe8775619e8/scikit-surprise-1.1.1.tar.gz (11.8MB)
#      |████████████████████████████████| 11.8MB 273kB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.0.0)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise->surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp36-cp36m-linux_x86_64.whl size=1618271 sha256=4c8b1eb09f9ec343fcf82ac554abb2ce9b2759a2ab8ff290fa930aec438ae511
#   Stored in directory: /root/.cache/pip/wheels/78/9c/3d/41b419c9d2aff5b6e2b4c0fc8d25c538202834058f9ed110d0
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.1 surprise-0.1

# %% [markdown]
# ## 2 Import necessary libraries

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise import accuracy

# %% [markdown]
# ## 3 Load Data (Movies Dataset from Surprise)

# %%
data = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k

# %% [markdown]
# ## 4 Build Model using SVD

# %% [markdown]
# ### 4.1 Split data in train and test

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
train.n_users, train.n_items
# Out:
# (943, 1644)

# %% [markdown]
# ### 4.2 Train Model

# %%
# From surprise import SVD
model_SVD = SVD()

# %%
model_SVD.fit(train)

# %% [markdown]
# ### 4.3 Make Prediction

# %%
predictions = model_SVD.test(test)

# %%
predictions
# Out:
# [Prediction(uid='391', iid='591', r_ui=4.0, est=3.335669524343874, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1291', r_ui=1.0, est=1.5681825567781469, details={'was_impossible': False}),
#  Prediction(uid='637', iid='268', r_ui=2.0, est=2.879937431043156, details={'was_impossible': False}),
#  Prediction(uid='332', iid='451', r_ui=5.0, est=3.917108586984055, details={'was_impossible': False}),
#  Prediction(uid='271', iid='204', r_ui=4.0, est=3.6637728667167466, details={'was_impossible': False}),
#  Prediction(uid='27', iid='286', r_ui=3.0, est=3.56646835247723, details={'was_impossible': False}),
#  Prediction(uid='387', iid='663', r_ui=4.0, est=3.4721003020223242, details={'was_impossible': False}),
#  Prediction(uid='92', iid='722', r_ui=3.0, est=3.027970793102507, details={'was_impossible': False}),
#  Prediction(uid='820', iid='347', r_ui=4.0, est=3.5103032480286696, details={'was_impossible': False}),
#  Prediction(uid='479', iid='1444', r_ui=1.0, est=2.715845833703309, details={'was_impossible': False}),
#  Prediction(uid='458', iid='195', r_ui=4.0, est=3.819725967396829, details={'was_impossible': False}),
#  Prediction(uid='669', iid='175', r_ui=4.0, est=3.6751409625552838, details={'was_impossible': False}),
#  Prediction(uid='295', iid='648', r_ui=4.0, est=4.607498788631272, details={'was_impossible': False}),
#  Prediction(uid='297', iid='174', r_ui=5.0, est=3.9221823967051983, details={'was_impossible': False}),
#  Prediction(uid='153', iid='678', r_ui=2.0, est=2.381210536502716, details={'was_impossible': False}),
#  Prediction(uid='924', iid='519', r_ui=4.0, est=4.129788825710559, details={'was_impossible': False}),
#  Prediction(uid='324', iid='255', r_ui=4.0, est=4.313213659703791, details={'was_impossible': False}),
#  Prediction(uid='503', iid='168', r_ui=5.0, est=4.377282139132333, details={'was_impossible': False}),
#  Prediction(uid='917', iid='628', r_ui=5.0, est=3.215840571210393, details={'was_impossible': False}),
#  Prediction(uid='231', iid='924', r_ui=5.0, est=3.6550392195711354, details={'was_impossible': False}),
#  Prediction(uid='13', iid='889', r_ui=3.0, est=3.190515929290556, details={'was_impossible': False}),
#  Prediction(uid='539', iid='367', r_ui=3.0, est=3.988318172919161, details={'was_impossible': False}),
#  Prediction(uid='447', iid='1142', r_ui=5.0, est=3.7186991673039107, details={'was_impossible': False}),
#  Prediction(uid='84', iid='486', r_ui=5.0, est=4.147406098866188, details={'was_impossible': False}),
#  Prediction(uid='450', iid='63', r_ui=4.0, est=3.683265439502698, details={'was_impossible': False}),
#  Prediction(uid='250', iid='477', r_ui=3.0, est=3.302852378405417, details={'was_impossible': False}),
#  Prediction(uid='342', iid='523', r_ui=4.0, est=3.5189778881139064, details={'was_impossible': False}),
#  Prediction(uid='504', iid='629', r_ui=4.0, est=3.318111407336858, details={'was_impossible': False}),
#  Prediction(uid='592', iid='744', r_ui=3.0, est=4.184560904613188, details={'was_impossible': False}),
#  Prediction(uid='417', iid='616', r_ui=2.0, est=3.5799982104685726, details={'was_impossible': False}),
#  Prediction(uid='676', iid='344', r_ui=5.0, est=3.8234852152294136, details={'was_impossible': False}),
#  Prediction(uid='660', iid='405', r_ui=2.0, est=2.714268470728584, details={'was_impossible': False}),
#  Prediction(uid='164', iid='328', r_ui=5.0, est=4.7206112841502, details={'was_impossible': False}),
#  Prediction(uid='269', iid='771', r_ui=1.0, est=1.995395850272005, details={'was_impossible': False}),
#  Prediction(uid='76', iid='851', r_ui=4.0, est=3.629159238659086, details={'was_impossible': False}),
#  Prediction(uid='491', iid='129', r_ui=4.0, est=3.4914331949412576, details={'was_impossible': False}),
#  Prediction(uid='276', iid='96', r_ui=5.0, est=4.188150156160499, details={'was_impossible': False}),
#  Prediction(uid='308', iid='283', r_ui=3.0, est=3.8867899663625467, details={'was_impossible': False}),
#  Prediction(uid='504', iid='310', r_ui=4.0, est=3.6483629071709958, details={'was_impossible': False}),
#  Prediction(uid='572', iid='222', r_ui=2.0, est=3.328736691711027, details={'was_impossible': False}),
#  Prediction(uid='788', iid='195', r_ui=3.0, est=3.783071753409396, details={'was_impossible': False}),
#  Prediction(uid='426', iid='1204', r_ui=4.0, est=3.541378926333014, details={'was_impossible': False}),
#  Prediction(uid='290', iid='31', r_ui=4.0, est=3.4476327845845716, details={'was_impossible': False}),
#  Prediction(uid='130', iid='471', r_ui=2.0, est=4.255428524993594, details={'was_impossible': False}),
#  Prediction(uid='533', iid='303', r_ui=4.0, est=3.4189226294649804, details={'was_impossible': False}),
#  Prediction(uid='456', iid='274', r_ui=3.0, est=3.2455273246889726, details={'was_impossible': False}),
#  Prediction(uid='457', iid='722', r_ui=4.0, est=3.6162822169607507, details={'was_impossible': False}),
#  Prediction(uid='313', iid='519', r_ui=5.0, est=3.9978878400187847, details={'was_impossible': False}),
#  Prediction(uid='787', iid='328', r_ui=3.0, est=3.440991040454995, details={'was_impossible': False}),
#  Prediction(uid='850', iid='69', r_ui=5.0, est=4.504588197228543, details={'was_impossible': False}),
#  Prediction(uid='320', iid='235', r_ui=3.0, est=3.1243589980878954, details={'was_impossible': False}),
#  Prediction(uid='201', iid='406', r_ui=1.0, est=2.2327199245155835, details={'was_impossible': False}),
#  Prediction(uid='484', iid='79', r_ui=5.0, est=4.469634107328938, details={'was_impossible': False}),
#  Prediction(uid='194', iid='674', r_ui=2.0, est=2.4129301575347086, details={'was_impossible': False}),
#  Prediction(uid='766', iid='550', r_ui=3.0, est=2.8437956545432503, details={'was_impossible': False}),
#  Prediction(uid='56', iid='144', r_ui=5.0, est=4.352518844971552, details={'was_impossible': False}),
#  Prediction(uid='878', iid='451', r_ui=2.0, est=3.1635204248026576, details={'was_impossible': False}),
#  Prediction(uid='145', iid='683', r_ui=3.0, est=3.1091893227711713, details={'was_impossible': False}),
#  Prediction(uid='592', iid='28', r_ui=4.0, est=4.253863096586244, details={'was_impossible': False}),
#  Prediction(uid='49', iid='1082', r_ui=3.0, est=2.3232668089139854, details={'was_impossible': False}),
#  Prediction(uid='347', iid='241', r_ui=3.0, est=3.6768979358697624, details={'was_impossible': False}),
#  Prediction(uid='487', iid='356', r_ui=4.0, est=3.538305210747038, details={'was_impossible': False}),
#  Prediction(uid='498', iid='127', r_ui=4.0, est=3.738931323033686, details={'was_impossible': False}),
#  Prediction(uid='883', iid='634', r_ui=3.0, est=3.41124844524691, details={'was_impossible': False}),
#  Prediction(uid='820', iid='358', r_ui=1.0, est=2.4308893065811628, details={'was_impossible': False}),
#  Prediction(uid='911', iid='709', r_ui=5.0, est=3.940063365025588, details={'was_impossible': False}),
#  Prediction(uid='892', iid='71', r_ui=3.0, est=4.191478147543832, details={'was_impossible': False}),
#  Prediction(uid='524', iid='321', r_ui=3.0, est=2.882814051527732, details={'was_impossible': False}),
#  Prediction(uid='887', iid='1278', r_ui=2.0, est=3.897620658846496, details={'was_impossible': False}),
#  Prediction(uid='839', iid='1664', r_ui=1.0, est=3.556321718247335, details={'was_impossible': False}),
#  Prediction(uid='608', iid='58', r_ui=2.0, est=4.077223235396504, details={'was_impossible': False}),
#  Prediction(uid='648', iid='14', r_ui=2.0, est=3.29130387240629, details={'was_impossible': False}),
#  Prediction(uid='709', iid='183', r_ui=5.0, est=4.123390971123917, details={'was_impossible': False}),
#  Prediction(uid='862', iid='405', r_ui=2.0, est=4.032318265060482, details={'was_impossible': False}),
#  Prediction(uid='654', iid='785', r_ui=4.0, est=3.6497605955974186, details={'was_impossible': False}),
#  Prediction(uid='218', iid='294', r_ui=2.0, est=2.5343072146045174, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1211', r_ui=4.0, est=2.8649451858857478, details={'was_impossible': False}),
#  Prediction(uid='606', iid='763', r_ui=5.0, est=3.5093672076918767, details={'was_impossible': False}),
#  Prediction(uid='326', iid='837', r_ui=4.0, est=3.8213981927813565, details={'was_impossible': False}),
#  Prediction(uid='24', iid='372', r_ui=4.0, est=4.212782507944269, details={'was_impossible': False}),
#  Prediction(uid='306', iid='864', r_ui=3.0, est=3.1046423653802666, details={'was_impossible': False}),
#  Prediction(uid='234', iid='663', r_ui=4.0, est=3.2106145048664785, details={'was_impossible': False}),
#  Prediction(uid='669', iid='522', r_ui=4.0, est=3.3279615696386484, details={'was_impossible': False}),
#  Prediction(uid='385', iid='657', r_ui=4.0, est=3.7521692751382334, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1644', r_ui=2.0, est=2.9058793733936703, details={'was_impossible': False}),
#  Prediction(uid='663', iid='187', r_ui=5.0, est=4.10452765140804, details={'was_impossible': False}),
#  Prediction(uid='178', iid='111', r_ui=4.0, est=3.4907019253453746, details={'was_impossible': False}),
#  Prediction(uid='164', iid='370', r_ui=5.0, est=3.4272225480391785, details={'was_impossible': False}),
#  Prediction(uid='222', iid='326', r_ui=4.0, est=2.988126113893018, details={'was_impossible': False}),
#  Prediction(uid='634', iid='471', r_ui=4.0, est=3.435561958909291, details={'was_impossible': False}),
#  Prediction(uid='705', iid='89', r_ui=2.0, est=4.257813110502744, details={'was_impossible': False}),
#  Prediction(uid='348', iid='974', r_ui=4.0, est=3.6410136022716957, details={'was_impossible': False}),
#  Prediction(uid='622', iid='31', r_ui=3.0, est=3.6209178186735294, details={'was_impossible': False}),
#  Prediction(uid='592', iid='201', r_ui=5.0, est=3.6806892395775757, details={'was_impossible': False}),
#  Prediction(uid='363', iid='95', r_ui=3.0, est=2.58991626497757, details={'was_impossible': False}),
#  Prediction(uid='655', iid='320', r_ui=5.0, est=2.7076048459591977, details={'was_impossible': False}),
#  Prediction(uid='559', iid='502', r_ui=4.0, est=3.3769274084529557, details={'was_impossible': False}),
#  Prediction(uid='276', iid='43', r_ui=1.0, est=3.096009744748834, details={'was_impossible': False}),
#  Prediction(uid='457', iid='194', r_ui=5.0, est=4.791054530844609, details={'was_impossible': False}),
#  Prediction(uid='538', iid='121', r_ui=3.0, est=3.1249463386477174, details={'was_impossible': False}),
#  Prediction(uid='582', iid='455', r_ui=1.0, est=3.29763898015843, details={'was_impossible': False}),
#  Prediction(uid='774', iid='2', r_ui=1.0, est=1.953082851367823, details={'was_impossible': False}),
#  Prediction(uid='773', iid='70', r_ui=3.0, est=3.729903048446981, details={'was_impossible': False}),
#  Prediction(uid='67', iid='7', r_ui=5.0, est=4.285284325335273, details={'was_impossible': False}),
#  Prediction(uid='151', iid='1098', r_ui=1.0, est=3.9977729719591415, details={'was_impossible': False}),
#  Prediction(uid='496', iid='333', r_ui=3.0, est=2.525318853129482, details={'was_impossible': False}),
#  Prediction(uid='774', iid='230', r_ui=2.0, est=2.5046574322239104, details={'was_impossible': False}),
#  Prediction(uid='214', iid='340', r_ui=3.0, est=3.4904008790012053, details={'was_impossible': False}),
#  Prediction(uid='901', iid='321', r_ui=1.0, est=3.3757862923685384, details={'was_impossible': False}),
#  Prediction(uid='293', iid='789', r_ui=2.0, est=3.2067631761640967, details={'was_impossible': False}),
#  Prediction(uid='72', iid='127', r_ui=5.0, est=4.0768507622837165, details={'was_impossible': False}),
#  Prediction(uid='18', iid='462', r_ui=3.0, est=3.837889716871878, details={'was_impossible': False}),
#  Prediction(uid='90', iid='496', r_ui=4.0, est=4.669342818640311, details={'was_impossible': False}),
#  Prediction(uid='682', iid='628', r_ui=4.0, est=3.4570644480941826, details={'was_impossible': False}),
#  Prediction(uid='262', iid='778', r_ui=4.0, est=3.2193422701815435, details={'was_impossible': False}),
#  Prediction(uid='933', iid='230', r_ui=3.0, est=2.784933518010687, details={'was_impossible': False}),
#  Prediction(uid='889', iid='322', r_ui=3.0, est=2.9906389073117507, details={'was_impossible': False}),
#  Prediction(uid='690', iid='216', r_ui=4.0, est=3.6353427024714646, details={'was_impossible': False}),
#  Prediction(uid='650', iid='82', r_ui=3.0, est=3.494601229335136, details={'was_impossible': False}),
#  Prediction(uid='537', iid='496', r_ui=4.0, est=3.1087803379246304, details={'was_impossible': False}),
#  Prediction(uid='805', iid='387', r_ui=3.0, est=2.9554194035484462, details={'was_impossible': False}),
#  Prediction(uid='642', iid='527', r_ui=4.0, est=4.410263272336672, details={'was_impossible': False}),
#  Prediction(uid='798', iid='801', r_ui=3.0, est=2.879231096438671, details={'was_impossible': False}),
#  Prediction(uid='185', iid='528', r_ui=4.0, est=4.321260374888595, details={'was_impossible': False}),
#  Prediction(uid='270', iid='531', r_ui=4.0, est=4.984171943946839, details={'was_impossible': False}),
#  Prediction(uid='308', iid='461', r_ui=4.0, est=3.616145034694931, details={'was_impossible': False}),
#  Prediction(uid='932', iid='1397', r_ui=4.0, est=4.021523672969572, details={'was_impossible': False}),
#  Prediction(uid='285', iid='286', r_ui=3.0, est=4.014535211032748, details={'was_impossible': False}),
#  Prediction(uid='42', iid='443', r_ui=3.0, est=3.9382983534487663, details={'was_impossible': False}),
#  Prediction(uid='805', iid='1071', r_ui=4.0, est=3.03279830120279, details={'was_impossible': False}),
#  Prediction(uid='224', iid='378', r_ui=4.0, est=3.467713406425558, details={'was_impossible': False}),
#  Prediction(uid='13', iid='624', r_ui=5.0, est=3.191144828012393, details={'was_impossible': False}),
#  Prediction(uid='790', iid='597', r_ui=3.0, est=2.856080174482334, details={'was_impossible': False}),
#  Prediction(uid='119', iid='471', r_ui=4.0, est=4.0452832705421855, details={'was_impossible': False}),
#  Prediction(uid='287', iid='682', r_ui=4.0, est=4.105239055187826, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1025', r_ui=1.0, est=1.0713940175204457, details={'was_impossible': False}),
#  Prediction(uid='617', iid='269', r_ui=1.0, est=3.056948603698624, details={'was_impossible': False}),
#  Prediction(uid='106', iid='15', r_ui=3.0, est=3.7909180919791665, details={'was_impossible': False}),
#  Prediction(uid='666', iid='582', r_ui=4.0, est=3.871992390970888, details={'was_impossible': False}),
#  Prediction(uid='864', iid='58', r_ui=5.0, est=3.7570491805640707, details={'was_impossible': False}),
#  Prediction(uid='13', iid='570', r_ui=5.0, est=3.0598826444902607, details={'was_impossible': False}),
#  Prediction(uid='921', iid='196', r_ui=5.0, est=3.322639839677831, details={'was_impossible': False}),
#  Prediction(uid='479', iid='1039', r_ui=4.0, est=4.049206270917888, details={'was_impossible': False}),
#  Prediction(uid='643', iid='163', r_ui=4.0, est=3.7338807574168023, details={'was_impossible': False}),
#  Prediction(uid='463', iid='1014', r_ui=2.0, est=2.286258885667082, details={'was_impossible': False}),
#  Prediction(uid='363', iid='709', r_ui=4.0, est=3.6992886556776314, details={'was_impossible': False}),
#  Prediction(uid='919', iid='4', r_ui=1.0, est=3.9147563767639526, details={'was_impossible': False}),
#  Prediction(uid='56', iid='172', r_ui=5.0, est=4.345759322581254, details={'was_impossible': False}),
#  Prediction(uid='506', iid='539', r_ui=4.0, est=2.485713517391748, details={'was_impossible': False}),
#  Prediction(uid='448', iid='319', r_ui=5.0, est=3.0221669126545327, details={'was_impossible': False}),
#  Prediction(uid='730', iid='121', r_ui=4.0, est=2.3018253983063763, details={'was_impossible': False}),
#  Prediction(uid='649', iid='275', r_ui=2.0, est=4.186664634920559, details={'was_impossible': False}),
#  Prediction(uid='435', iid='354', r_ui=3.0, est=2.9005524225589014, details={'was_impossible': False}),
#  Prediction(uid='399', iid='597', r_ui=3.0, est=2.904887351604818, details={'was_impossible': False}),
#  Prediction(uid='894', iid='287', r_ui=4.0, est=3.631767011256914, details={'was_impossible': False}),
#  Prediction(uid='916', iid='366', r_ui=3.0, est=3.0375022026660243, details={'was_impossible': False}),
#  Prediction(uid='254', iid='501', r_ui=3.0, est=3.25131370369973, details={'was_impossible': False}),
#  Prediction(uid='605', iid='121', r_ui=1.0, est=2.752220000879854, details={'was_impossible': False}),
#  Prediction(uid='693', iid='333', r_ui=3.0, est=3.235909142265821, details={'was_impossible': False}),
#  Prediction(uid='455', iid='627', r_ui=3.0, est=3.0460663486340196, details={'was_impossible': False}),
#  Prediction(uid='298', iid='237', r_ui=5.0, est=3.566915813136512, details={'was_impossible': False}),
#  Prediction(uid='870', iid='461', r_ui=4.0, est=3.3213201804487835, details={'was_impossible': False}),
#  Prediction(uid='153', iid='56', r_ui=5.0, est=3.8276771433544057, details={'was_impossible': False}),
#  Prediction(uid='148', iid='169', r_ui=5.0, est=4.492123076619743, details={'was_impossible': False}),
#  Prediction(uid='504', iid='416', r_ui=4.0, est=3.6813181707466454, details={'was_impossible': False}),
#  Prediction(uid='739', iid='69', r_ui=5.0, est=3.598665133642585, details={'was_impossible': False}),
#  Prediction(uid='540', iid='111', r_ui=4.0, est=3.6504077293510133, details={'was_impossible': False}),
#  Prediction(uid='374', iid='291', r_ui=3.0, est=3.6913130148904205, details={'was_impossible': False}),
#  Prediction(uid='686', iid='474', r_ui=5.0, est=4.979515791411279, details={'was_impossible': False}),
#  Prediction(uid='159', iid='294', r_ui=4.0, est=3.338036090844718, details={'was_impossible': False}),
#  Prediction(uid='450', iid='238', r_ui=5.0, est=4.088016416815626, details={'was_impossible': False}),
#  Prediction(uid='599', iid='756', r_ui=5.0, est=3.6137958034931974, details={'was_impossible': False}),
#  Prediction(uid='798', iid='1425', r_ui=4.0, est=2.948607342138381, details={'was_impossible': False}),
#  Prediction(uid='279', iid='190', r_ui=3.0, est=4.28291847763569, details={'was_impossible': False}),
#  Prediction(uid='673', iid='286', r_ui=4.0, est=3.9476627303198817, details={'was_impossible': False}),
#  Prediction(uid='253', iid='220', r_ui=4.0, est=3.6696569160434658, details={'was_impossible': False}),
#  Prediction(uid='716', iid='210', r_ui=5.0, est=4.127350033368062, details={'was_impossible': False}),
#  Prediction(uid='714', iid='1152', r_ui=2.0, est=3.707855455091563, details={'was_impossible': False}),
#  Prediction(uid='505', iid='724', r_ui=4.0, est=3.1416742927758543, details={'was_impossible': False}),
#  Prediction(uid='343', iid='26', r_ui=3.0, est=3.5421951547411568, details={'was_impossible': False}),
#  Prediction(uid='234', iid='197', r_ui=5.0, est=3.7129438982949794, details={'was_impossible': False}),
#  Prediction(uid='485', iid='346', r_ui=4.0, est=3.1006265386825005, details={'was_impossible': False}),
#  Prediction(uid='125', iid='174', r_ui=5.0, est=4.578945285847687, details={'was_impossible': False}),
#  Prediction(uid='344', iid='472', r_ui=3.0, est=2.7777702539194253, details={'was_impossible': False}),
#  Prediction(uid='125', iid='87', r_ui=5.0, est=3.9731193019682514, details={'was_impossible': False}),
#  Prediction(uid='297', iid='129', r_ui=4.0, est=3.5296020480703953, details={'was_impossible': False}),
#  Prediction(uid='399', iid='268', r_ui=3.0, est=3.203955552767789, details={'was_impossible': False}),
#  Prediction(uid='271', iid='235', r_ui=3.0, est=2.811970015266323, details={'was_impossible': False}),
#  Prediction(uid='294', iid='222', r_ui=4.0, est=3.775948193756903, details={'was_impossible': False}),
#  Prediction(uid='312', iid='495', r_ui=4.0, est=3.943628444765236, details={'was_impossible': False}),
#  Prediction(uid='503', iid='47', r_ui=5.0, est=3.685006726435818, details={'was_impossible': False}),
#  Prediction(uid='894', iid='276', r_ui=5.0, est=3.6744363750846754, details={'was_impossible': False}),
#  Prediction(uid='279', iid='249', r_ui=3.0, est=3.123764767699537, details={'was_impossible': False}),
#  Prediction(uid='16', iid='480', r_ui=5.0, est=4.608650108623994, details={'was_impossible': False}),
#  Prediction(uid='328', iid='28', r_ui=5.0, est=3.7127047636573653, details={'was_impossible': False}),
#  Prediction(uid='537', iid='204', r_ui=3.0, est=2.734633601409822, details={'was_impossible': False}),
#  Prediction(uid='327', iid='652', r_ui=4.0, est=3.6786573073191478, details={'was_impossible': False}),
#  Prediction(uid='682', iid='790', r_ui=3.0, est=2.851573468172714, details={'was_impossible': False}),
#  Prediction(uid='620', iid='288', r_ui=4.0, est=4.063586802797926, details={'was_impossible': False}),
#  Prediction(uid='187', iid='197', r_ui=4.0, est=4.08701319498848, details={'was_impossible': False}),
#  Prediction(uid='52', iid='1086', r_ui=4.0, est=4.0305836752005515, details={'was_impossible': False}),
#  Prediction(uid='7', iid='126', r_ui=3.0, est=4.208707166186013, details={'was_impossible': False}),
#  Prediction(uid='655', iid='312', r_ui=2.0, est=2.454533638513013, details={'was_impossible': False}),
#  Prediction(uid='76', iid='100', r_ui=5.0, est=4.877742718850908, details={'was_impossible': False}),
#  Prediction(uid='862', iid='216', r_ui=5.0, est=4.49094370331708, details={'was_impossible': False}),
#  Prediction(uid='707', iid='293', r_ui=4.0, est=3.7715395629453354, details={'was_impossible': False}),
#  Prediction(uid='387', iid='380', r_ui=2.0, est=2.641573141205258, details={'was_impossible': False}),
#  Prediction(uid='644', iid='250', r_ui=4.0, est=4.103801968229108, details={'was_impossible': False}),
#  Prediction(uid='501', iid='597', r_ui=3.0, est=3.370265199527691, details={'was_impossible': False}),
#  Prediction(uid='892', iid='79', r_ui=5.0, est=4.628411629196641, details={'was_impossible': False}),
#  Prediction(uid='130', iid='794', r_ui=5.0, est=4.4328370682792935, details={'was_impossible': False}),
#  Prediction(uid='840', iid='203', r_ui=5.0, est=4.31229637717239, details={'was_impossible': False}),
#  Prediction(uid='619', iid='27', r_ui=4.0, est=2.8859549306954997, details={'was_impossible': False}),
#  Prediction(uid='940', iid='213', r_ui=4.0, est=3.7088400396363506, details={'was_impossible': False}),
#  Prediction(uid='760', iid='375', r_ui=4.0, est=2.437848648066114, details={'was_impossible': False}),
#  Prediction(uid='642', iid='69', r_ui=5.0, est=4.375650502960834, details={'was_impossible': False}),
#  Prediction(uid='432', iid='151', r_ui=4.0, est=3.5643051317653556, details={'was_impossible': False}),
#  Prediction(uid='450', iid='535', r_ui=3.0, est=3.825941076576533, details={'was_impossible': False}),
#  Prediction(uid='254', iid='610', r_ui=2.0, est=3.202861454649052, details={'was_impossible': False}),
#  Prediction(uid='1', iid='18', r_ui=4.0, est=3.361438915540827, details={'was_impossible': False}),
#  Prediction(uid='655', iid='6', r_ui=4.0, est=2.9362429377164263, details={'was_impossible': False}),
#  Prediction(uid='932', iid='513', r_ui=5.0, est=4.330646448575551, details={'was_impossible': False}),
#  Prediction(uid='702', iid='1127', r_ui=2.0, est=2.660399941885856, details={'was_impossible': False}),
#  Prediction(uid='407', iid='208', r_ui=4.0, est=3.8928073168887907, details={'was_impossible': False}),
#  Prediction(uid='292', iid='631', r_ui=5.0, est=4.092024711143511, details={'was_impossible': False}),
#  Prediction(uid='474', iid='196', r_ui=5.0, est=4.061833119718491, details={'was_impossible': False}),
#  Prediction(uid='436', iid='649', r_ui=5.0, est=3.833796984819758, details={'was_impossible': False}),
#  Prediction(uid='859', iid='846', r_ui=5.0, est=3.3195426457230433, details={'was_impossible': False}),
#  Prediction(uid='248', iid='294', r_ui=3.0, est=2.59234437012163, details={'was_impossible': False}),
#  Prediction(uid='907', iid='405', r_ui=4.0, est=4.478672330631468, details={'was_impossible': False}),
#  Prediction(uid='577', iid='22', r_ui=5.0, est=4.180027454436793, details={'was_impossible': False}),
#  Prediction(uid='833', iid='5', r_ui=1.0, est=2.5220148882747906, details={'was_impossible': False}),
#  Prediction(uid='495', iid='120', r_ui=5.0, est=2.7564593865516755, details={'was_impossible': False}),
#  Prediction(uid='1', iid='37', r_ui=2.0, est=2.834855646400078, details={'was_impossible': False}),
#  Prediction(uid='716', iid='392', r_ui=2.0, est=3.758771650518591, details={'was_impossible': False}),
#  Prediction(uid='283', iid='1487', r_ui=2.0, est=3.9829560877657038, details={'was_impossible': False}),
#  Prediction(uid='294', iid='902', r_ui=4.0, est=3.882464212148862, details={'was_impossible': False}),
#  Prediction(uid='650', iid='637', r_ui=3.0, est=2.504423319943349, details={'was_impossible': False}),
#  Prediction(uid='405', iid='382', r_ui=1.0, est=2.027502212848372, details={'was_impossible': False}),
#  Prediction(uid='394', iid='597', r_ui=2.0, est=3.5624333057735273, details={'was_impossible': False}),
#  Prediction(uid='387', iid='68', r_ui=4.0, est=3.2755346177288382, details={'was_impossible': False}),
#  Prediction(uid='293', iid='528', r_ui=4.0, est=3.781878087481767, details={'was_impossible': False}),
#  Prediction(uid='200', iid='1411', r_ui=3.0, est=3.6071080427932825, details={'was_impossible': False}),
#  Prediction(uid='161', iid='428', r_ui=3.0, est=2.731270807023253, details={'was_impossible': False}),
#  Prediction(uid='197', iid='879', r_ui=4.0, est=3.3947769152259286, details={'was_impossible': False}),
#  Prediction(uid='310', iid='1142', r_ui=5.0, est=3.8363773177597262, details={'was_impossible': False}),
#  Prediction(uid='469', iid='10', r_ui=5.0, est=4.36162336606102, details={'was_impossible': False}),
#  Prediction(uid='113', iid='976', r_ui=5.0, est=3.1635634128576333, details={'was_impossible': False}),
#  Prediction(uid='421', iid='219', r_ui=3.0, est=3.2396405557870747, details={'was_impossible': False}),
#  Prediction(uid='903', iid='412', r_ui=2.0, est=2.6563674968630187, details={'was_impossible': False}),
#  Prediction(uid='500', iid='483', r_ui=4.0, est=4.367953539433403, details={'was_impossible': False}),
#  Prediction(uid='519', iid='1062', r_ui=5.0, est=4.55416647186686, details={'was_impossible': False}),
#  Prediction(uid='555', iid='249', r_ui=4.0, est=3.7815657115726116, details={'was_impossible': False}),
#  Prediction(uid='660', iid='202', r_ui=2.0, est=3.2232757401546865, details={'was_impossible': False}),
#  Prediction(uid='795', iid='577', r_ui=3.0, est=2.219003197898014, details={'was_impossible': False}),
#  Prediction(uid='457', iid='25', r_ui=4.0, est=3.5921304707869606, details={'was_impossible': False}),
#  Prediction(uid='276', iid='647', r_ui=4.0, est=4.309221403376682, details={'was_impossible': False}),
#  Prediction(uid='534', iid='978', r_ui=4.0, est=3.4886960023540476, details={'was_impossible': False}),
#  Prediction(uid='353', iid='258', r_ui=5.0, est=3.407674191174709, details={'was_impossible': False}),
#  Prediction(uid='279', iid='396', r_ui=3.0, est=3.2169439210699573, details={'was_impossible': False}),
#  Prediction(uid='230', iid='143', r_ui=5.0, est=3.9261437227434763, details={'was_impossible': False}),
#  Prediction(uid='18', iid='921', r_ui=5.0, est=3.7166479241185186, details={'was_impossible': False}),
#  Prediction(uid='923', iid='926', r_ui=4.0, est=3.323905199707594, details={'was_impossible': False}),
#  Prediction(uid='14', iid='22', r_ui=3.0, est=4.652254122555504, details={'was_impossible': False}),
#  Prediction(uid='389', iid='66', r_ui=3.0, est=3.5108032358930323, details={'was_impossible': False}),
#  Prediction(uid='655', iid='313', r_ui=4.0, est=3.254376432742588, details={'was_impossible': False}),
#  Prediction(uid='898', iid='316', r_ui=5.0, est=4.268003172264674, details={'was_impossible': False}),
#  Prediction(uid='539', iid='124', r_ui=4.0, est=3.8557584366445825, details={'was_impossible': False}),
#  Prediction(uid='366', iid='7', r_ui=2.0, est=4.529871638216012, details={'was_impossible': False}),
#  Prediction(uid='65', iid='194', r_ui=4.0, est=4.435366684956697, details={'was_impossible': False}),
#  Prediction(uid='716', iid='105', r_ui=2.0, est=2.7481460112703737, details={'was_impossible': False}),
#  Prediction(uid='92', iid='728', r_ui=3.0, est=2.8557842965272604, details={'was_impossible': False}),
#  Prediction(uid='389', iid='699', r_ui=5.0, est=3.7380513538800497, details={'was_impossible': False}),
#  Prediction(uid='760', iid='631', r_ui=3.0, est=3.3962226794523, details={'was_impossible': False}),
#  Prediction(uid='834', iid='515', r_ui=5.0, est=4.370682001447031, details={'was_impossible': False}),
#  Prediction(uid='58', iid='684', r_ui=4.0, est=3.65020207594631, details={'was_impossible': False}),
#  Prediction(uid='268', iid='265', r_ui=3.0, est=3.6745253652185546, details={'was_impossible': False}),
#  Prediction(uid='354', iid='165', r_ui=4.0, est=4.199122752891554, details={'was_impossible': False}),
#  Prediction(uid='222', iid='172', r_ui=5.0, est=3.707999282717558, details={'was_impossible': False}),
#  Prediction(uid='180', iid='98', r_ui=5.0, est=4.0708389349024605, details={'was_impossible': False}),
#  Prediction(uid='512', iid='97', r_ui=5.0, est=4.398651758144905, details={'was_impossible': False}),
#  Prediction(uid='337', iid='450', r_ui=2.0, est=3.103737620054628, details={'was_impossible': False}),
#  Prediction(uid='48', iid='28', r_ui=2.0, est=3.8149830303733467, details={'was_impossible': False}),
#  Prediction(uid='198', iid='581', r_ui=3.0, est=3.0317940483129013, details={'was_impossible': False}),
#  Prediction(uid='268', iid='55', r_ui=4.0, est=3.244805306579954, details={'was_impossible': False}),
#  Prediction(uid='734', iid='121', r_ui=4.0, est=3.6083707058556227, details={'was_impossible': False}),
#  Prediction(uid='311', iid='168', r_ui=4.0, est=3.9659414719150385, details={'was_impossible': False}),
#  Prediction(uid='472', iid='99', r_ui=3.0, est=4.808188999588678, details={'was_impossible': False}),
#  Prediction(uid='858', iid='127', r_ui=5.0, est=4.145874288267759, details={'was_impossible': False}),
#  Prediction(uid='239', iid='529', r_ui=5.0, est=4.468845478803278, details={'was_impossible': False}),
#  Prediction(uid='553', iid='511', r_ui=5.0, est=4.562564112220725, details={'was_impossible': False}),
#  Prediction(uid='20', iid='252', r_ui=4.0, est=2.654555151989708, details={'was_impossible': False}),
#  Prediction(uid='741', iid='196', r_ui=5.0, est=3.704398737901141, details={'was_impossible': False}),
#  Prediction(uid='286', iid='181', r_ui=3.0, est=4.300663629329655, details={'was_impossible': False}),
#  Prediction(uid='521', iid='763', r_ui=4.0, est=3.027359444215476, details={'was_impossible': False}),
#  Prediction(uid='508', iid='211', r_ui=3.0, est=3.9077851735459865, details={'was_impossible': False}),
#  Prediction(uid='864', iid='716', r_ui=2.0, est=3.508269255674956, details={'was_impossible': False}),
#  Prediction(uid='479', iid='274', r_ui=4.0, est=3.2183850424273537, details={'was_impossible': False}),
#  Prediction(uid='293', iid='53', r_ui=3.0, est=2.463729861458185, details={'was_impossible': False}),
#  Prediction(uid='276', iid='427', r_ui=5.0, est=4.366882135721865, details={'was_impossible': False}),
#  Prediction(uid='851', iid='313', r_ui=4.0, est=4.355562284663109, details={'was_impossible': False}),
#  Prediction(uid='76', iid='919', r_ui=3.0, est=3.679309496887479, details={'was_impossible': False}),
#  Prediction(uid='627', iid='651', r_ui=4.0, est=3.8155436977787525, details={'was_impossible': False}),
#  Prediction(uid='661', iid='181', r_ui=5.0, est=4.324039654468331, details={'was_impossible': False}),
#  Prediction(uid='846', iid='1018', r_ui=4.0, est=3.6558818671099402, details={'was_impossible': False}),
#  Prediction(uid='363', iid='469', r_ui=2.0, est=3.264778826601638, details={'was_impossible': False}),
#  Prediction(uid='158', iid='232', r_ui=3.0, est=3.3701757121978857, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1132', r_ui=2.0, est=2.550503257619078, details={'was_impossible': False}),
#  Prediction(uid='249', iid='168', r_ui=4.0, est=4.437118745667423, details={'was_impossible': False}),
#  Prediction(uid='378', iid='328', r_ui=3.0, est=3.2989043010931005, details={'was_impossible': False}),
#  Prediction(uid='200', iid='596', r_ui=4.0, est=4.01633105060984, details={'was_impossible': False}),
#  Prediction(uid='699', iid='820', r_ui=2.0, est=2.5440204213232684, details={'was_impossible': False}),
#  Prediction(uid='275', iid='380', r_ui=3.0, est=3.1713443408780453, details={'was_impossible': False}),
#  Prediction(uid='749', iid='160', r_ui=3.0, est=3.2947210095526493, details={'was_impossible': False}),
#  Prediction(uid='709', iid='1218', r_ui=4.0, est=3.365518986104244, details={'was_impossible': False}),
#  Prediction(uid='99', iid='125', r_ui=4.0, est=3.6665673357523465, details={'was_impossible': False}),
#  Prediction(uid='892', iid='378', r_ui=4.0, est=4.0629764848108945, details={'was_impossible': False}),
#  Prediction(uid='416', iid='173', r_ui=5.0, est=4.893068398021964, details={'was_impossible': False}),
#  Prediction(uid='116', iid='268', r_ui=5.0, est=3.2165399715449126, details={'was_impossible': False}),
#  Prediction(uid='454', iid='972', r_ui=2.0, est=2.7488858113011623, details={'was_impossible': False}),
#  Prediction(uid='407', iid='357', r_ui=4.0, est=4.1752282972955195, details={'was_impossible': False}),
#  Prediction(uid='922', iid='427', r_ui=5.0, est=3.9846523211559024, details={'was_impossible': False}),
#  Prediction(uid='465', iid='318', r_ui=4.0, est=3.7830573531207836, details={'was_impossible': False}),
#  Prediction(uid='886', iid='425', r_ui=4.0, est=3.111130026788707, details={'was_impossible': False}),
#  Prediction(uid='308', iid='1019', r_ui=4.0, est=3.9113659227044058, details={'was_impossible': False}),
#  Prediction(uid='311', iid='1119', r_ui=4.0, est=3.9676713093147677, details={'was_impossible': False}),
#  Prediction(uid='864', iid='288', r_ui=5.0, est=3.592648738268186, details={'was_impossible': False}),
#  Prediction(uid='236', iid='181', r_ui=4.0, est=3.634263119161375, details={'was_impossible': False}),
#  Prediction(uid='16', iid='657', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='130', iid='455', r_ui=4.0, est=3.6821534814258987, details={'was_impossible': False}),
#  Prediction(uid='216', iid='546', r_ui=2.0, est=3.2945547980428063, details={'was_impossible': False}),
#  Prediction(uid='565', iid='855', r_ui=5.0, est=4.461355065056193, details={'was_impossible': False}),
#  Prediction(uid='707', iid='133', r_ui=2.0, est=3.23527299419104, details={'was_impossible': False}),
#  Prediction(uid='761', iid='205', r_ui=4.0, est=3.45325582879916, details={'was_impossible': False}),
#  Prediction(uid='387', iid='919', r_ui=5.0, est=3.621332490984819, details={'was_impossible': False}),
#  Prediction(uid='460', iid='250', r_ui=2.0, est=3.114306309008588, details={'was_impossible': False}),
#  Prediction(uid='660', iid='496', r_ui=3.0, est=3.3949100051375902, details={'was_impossible': False}),
#  Prediction(uid='877', iid='275', r_ui=4.0, est=3.8852668262180172, details={'was_impossible': False}),
#  Prediction(uid='10', iid='286', r_ui=4.0, est=4.447068247162894, details={'was_impossible': False}),
#  Prediction(uid='424', iid='840', r_ui=4.0, est=2.4521114500774392, details={'was_impossible': False}),
#  Prediction(uid='308', iid='166', r_ui=3.0, est=4.169543115162254, details={'was_impossible': False}),
#  Prediction(uid='7', iid='69', r_ui=5.0, est=4.108687528757197, details={'was_impossible': False}),
#  Prediction(uid='699', iid='181', r_ui=3.0, est=3.57383536383039, details={'was_impossible': False}),
#  Prediction(uid='474', iid='484', r_ui=5.0, est=4.512605438118091, details={'was_impossible': False}),
#  Prediction(uid='296', iid='298', r_ui=1.0, est=4.1128735902820495, details={'was_impossible': False}),
#  Prediction(uid='379', iid='230', r_ui=4.0, est=3.731806351047108, details={'was_impossible': False}),
#  Prediction(uid='698', iid='486', r_ui=4.0, est=2.994041552584708, details={'was_impossible': False}),
#  Prediction(uid='835', iid='1045', r_ui=4.0, est=3.651671981096669, details={'was_impossible': False}),
#  Prediction(uid='371', iid='180', r_ui=4.0, est=3.9597446174546373, details={'was_impossible': False}),
#  Prediction(uid='229', iid='245', r_ui=3.0, est=2.685981347490131, details={'was_impossible': False}),
#  Prediction(uid='338', iid='474', r_ui=4.0, est=4.202355216199344, details={'was_impossible': False}),
#  Prediction(uid='168', iid='924', r_ui=2.0, est=3.618726988275713, details={'was_impossible': False}),
#  Prediction(uid='21', iid='200', r_ui=5.0, est=3.288330263255745, details={'was_impossible': False}),
#  Prediction(uid='708', iid='930', r_ui=3.0, est=2.5214250751280525, details={'was_impossible': False}),
#  Prediction(uid='624', iid='100', r_ui=5.0, est=4.3667420880168155, details={'was_impossible': False}),
#  Prediction(uid='303', iid='44', r_ui=4.0, est=3.422038278785274, details={'was_impossible': False}),
#  Prediction(uid='758', iid='134', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='191', iid='307', r_ui=3.0, est=3.2743926614876906, details={'was_impossible': False}),
#  Prediction(uid='268', iid='128', r_ui=3.0, est=3.3919688998788073, details={'was_impossible': False}),
#  Prediction(uid='815', iid='182', r_ui=3.0, est=3.9195777604000175, details={'was_impossible': False}),
#  Prediction(uid='454', iid='659', r_ui=2.0, est=3.4410260950690423, details={'was_impossible': False}),
#  Prediction(uid='342', iid='813', r_ui=5.0, est=4.00952756521071, details={'was_impossible': False}),
#  Prediction(uid='325', iid='23', r_ui=5.0, est=4.040761797693977, details={'was_impossible': False}),
#  Prediction(uid='378', iid='49', r_ui=3.0, est=3.07278254444348, details={'was_impossible': False}),
#  Prediction(uid='493', iid='462', r_ui=2.0, est=3.8061780392344553, details={'was_impossible': False}),
#  Prediction(uid='592', iid='589', r_ui=5.0, est=4.381859317413791, details={'was_impossible': False}),
#  Prediction(uid='174', iid='12', r_ui=5.0, est=4.659103091131332, details={'was_impossible': False}),
#  Prediction(uid='451', iid='264', r_ui=3.0, est=2.2967976141760658, details={'was_impossible': False}),
#  Prediction(uid='145', iid='5', r_ui=3.0, est=3.3130176464945054, details={'was_impossible': False}),
#  Prediction(uid='765', iid='971', r_ui=4.0, est=4.103370143972803, details={'was_impossible': False}),
#  Prediction(uid='467', iid='1142', r_ui=5.0, est=3.989328922771795, details={'was_impossible': False}),
#  Prediction(uid='669', iid='354', r_ui=1.0, est=2.875302315514152, details={'was_impossible': False}),
#  Prediction(uid='298', iid='172', r_ui=4.0, est=4.33037171142836, details={'was_impossible': False}),
#  Prediction(uid='623', iid='181', r_ui=5.0, est=4.041726256490495, details={'was_impossible': False}),
#  Prediction(uid='456', iid='68', r_ui=4.0, est=3.2918856538584165, details={'was_impossible': False}),
#  Prediction(uid='892', iid='276', r_ui=4.0, est=3.676576660391426, details={'was_impossible': False}),
#  Prediction(uid='692', iid='845', r_ui=3.0, est=3.3514715430550925, details={'was_impossible': False}),
#  Prediction(uid='72', iid='191', r_ui=5.0, est=3.804529850362083, details={'was_impossible': False}),
#  Prediction(uid='239', iid='1099', r_ui=5.0, est=3.8663791234726177, details={'was_impossible': False}),
#  Prediction(uid='244', iid='401', r_ui=3.0, est=3.0593851562745424, details={'was_impossible': False}),
#  Prediction(uid='601', iid='12', r_ui=3.0, est=4.168932816780018, details={'was_impossible': False}),
#  Prediction(uid='308', iid='74', r_ui=4.0, est=3.369763909675442, details={'was_impossible': False}),
#  Prediction(uid='187', iid='186', r_ui=4.0, est=4.04520152993018, details={'was_impossible': False}),
#  Prediction(uid='923', iid='334', r_ui=5.0, est=4.061428771184957, details={'was_impossible': False}),
#  Prediction(uid='194', iid='1408', r_ui=1.0, est=2.4345321824641153, details={'was_impossible': False}),
#  Prediction(uid='25', iid='176', r_ui=4.0, est=4.225931378787206, details={'was_impossible': False}),
#  Prediction(uid='790', iid='51', r_ui=3.0, est=3.2790524173616062, details={'was_impossible': False}),
#  Prediction(uid='495', iid='50', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='916', iid='484', r_ui=4.0, est=3.774177268485374, details={'was_impossible': False}),
#  Prediction(uid='881', iid='11', r_ui=4.0, est=3.6509004479249967, details={'was_impossible': False}),
#  Prediction(uid='357', iid='126', r_ui=5.0, est=4.644273907227552, details={'was_impossible': False}),
#  Prediction(uid='195', iid='496', r_ui=4.0, est=3.9719183211942712, details={'was_impossible': False}),
#  Prediction(uid='682', iid='999', r_ui=2.0, est=2.860530564921815, details={'was_impossible': False}),
#  Prediction(uid='344', iid='1050', r_ui=3.0, est=3.536972255789927, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1136', r_ui=3.0, est=3.2583702915254014, details={'was_impossible': False}),
#  Prediction(uid='885', iid='538', r_ui=4.0, est=3.177848455017519, details={'was_impossible': False}),
#  Prediction(uid='49', iid='904', r_ui=2.0, est=2.993544321587071, details={'was_impossible': False}),
#  Prediction(uid='916', iid='237', r_ui=3.0, est=3.2633281925211297, details={'was_impossible': False}),
#  Prediction(uid='416', iid='821', r_ui=4.0, est=3.3485149938647156, details={'was_impossible': False}),
#  Prediction(uid='13', iid='709', r_ui=4.0, est=3.8829164815493695, details={'was_impossible': False}),
#  Prediction(uid='407', iid='476', r_ui=2.0, est=3.0876848428970676, details={'was_impossible': False}),
#  Prediction(uid='5', iid='425', r_ui=2.0, est=3.4440725881158296, details={'was_impossible': False}),
#  Prediction(uid='344', iid='301', r_ui=4.0, est=3.3036777158347257, details={'was_impossible': False}),
#  Prediction(uid='291', iid='794', r_ui=4.0, est=3.909702188631039, details={'was_impossible': False}),
#  Prediction(uid='458', iid='753', r_ui=4.0, est=3.8801495288472045, details={'was_impossible': False}),
#  Prediction(uid='432', iid='24', r_ui=1.0, est=3.601500512460096, details={'was_impossible': False}),
#  Prediction(uid='374', iid='159', r_ui=4.0, est=3.603229199072215, details={'was_impossible': False}),
#  Prediction(uid='416', iid='419', r_ui=4.0, est=4.711877509065601, details={'was_impossible': False}),
#  Prediction(uid='286', iid='652', r_ui=4.0, est=4.289075327774202, details={'was_impossible': False}),
#  Prediction(uid='429', iid='241', r_ui=3.0, est=3.541394143082501, details={'was_impossible': False}),
#  Prediction(uid='370', iid='604', r_ui=4.0, est=3.954017069585114, details={'was_impossible': False}),
#  Prediction(uid='198', iid='15', r_ui=3.0, est=3.2653471704321597, details={'was_impossible': False}),
#  Prediction(uid='682', iid='188', r_ui=4.0, est=3.6327511836139665, details={'was_impossible': False}),
#  Prediction(uid='218', iid='516', r_ui=5.0, est=3.6002781647677335, details={'was_impossible': False}),
#  Prediction(uid='758', iid='1088', r_ui=3.0, est=3.124185681622632, details={'was_impossible': False}),
#  Prediction(uid='450', iid='228', r_ui=4.0, est=4.168215136299169, details={'was_impossible': False}),
#  Prediction(uid='699', iid='760', r_ui=3.0, est=2.6483303169732455, details={'was_impossible': False}),
#  Prediction(uid='191', iid='891', r_ui=3.0, est=3.2031988039041104, details={'was_impossible': False}),
#  Prediction(uid='279', iid='250', r_ui=3.0, est=3.0135503799686103, details={'was_impossible': False}),
#  Prediction(uid='919', iid='676', r_ui=4.0, est=3.1684715274999413, details={'was_impossible': False}),
#  Prediction(uid='234', iid='211', r_ui=3.0, est=3.167096873649331, details={'was_impossible': False}),
#  Prediction(uid='618', iid='477', r_ui=2.0, est=2.7710270542619364, details={'was_impossible': False}),
#  Prediction(uid='440', iid='242', r_ui=5.0, est=4.570218605677022, details={'was_impossible': False}),
#  Prediction(uid='545', iid='271', r_ui=3.0, est=3.3277983424567337, details={'was_impossible': False}),
#  Prediction(uid='87', iid='715', r_ui=3.0, est=3.26706347142054, details={'was_impossible': False}),
#  Prediction(uid='655', iid='844', r_ui=4.0, est=2.596973151382964, details={'was_impossible': False}),
#  Prediction(uid='256', iid='1051', r_ui=4.0, est=3.854497597824745, details={'was_impossible': False}),
#  Prediction(uid='479', iid='215', r_ui=3.0, est=3.6443296545491273, details={'was_impossible': False}),
#  Prediction(uid='715', iid='1088', r_ui=1.0, est=2.385705402885892, details={'was_impossible': False}),
#  Prediction(uid='222', iid='655', r_ui=4.0, est=3.657367207953217, details={'was_impossible': False}),
#  Prediction(uid='135', iid='452', r_ui=2.0, est=2.6010985004006786, details={'was_impossible': False}),
#  Prediction(uid='891', iid='118', r_ui=4.0, est=4.080470132388149, details={'was_impossible': False}),
#  Prediction(uid='682', iid='76', r_ui=3.0, est=3.2470009042073213, details={'was_impossible': False}),
#  Prediction(uid='786', iid='172', r_ui=5.0, est=4.117653861005454, details={'was_impossible': False}),
#  Prediction(uid='521', iid='230', r_ui=3.0, est=3.082160861700803, details={'was_impossible': False}),
#  Prediction(uid='305', iid='863', r_ui=4.0, est=3.2880465976448283, details={'was_impossible': False}),
#  Prediction(uid='174', iid='138', r_ui=1.0, est=3.118693724742623, details={'was_impossible': False}),
#  Prediction(uid='46', iid='690', r_ui=5.0, est=3.8462953097716297, details={'was_impossible': False}),
#  Prediction(uid='145', iid='767', r_ui=2.0, est=3.168641296610239, details={'was_impossible': False}),
#  Prediction(uid='868', iid='382', r_ui=4.0, est=2.7847576907120812, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1547', r_ui=2.0, est=2.0307055543093826, details={'was_impossible': False}),
#  Prediction(uid='253', iid='8', r_ui=4.0, est=4.037663068800827, details={'was_impossible': False}),
#  Prediction(uid='262', iid='258', r_ui=4.0, est=3.361220944450641, details={'was_impossible': False}),
#  Prediction(uid='136', iid='223', r_ui=4.0, est=4.614088417320382, details={'was_impossible': False}),
#  Prediction(uid='643', iid='185', r_ui=5.0, est=4.2418832858313555, details={'was_impossible': False}),
#  Prediction(uid='195', iid='1417', r_ui=3.0, est=3.44322021057795, details={'was_impossible': False}),
#  Prediction(uid='569', iid='151', r_ui=5.0, est=3.840126397326001, details={'was_impossible': False}),
#  Prediction(uid='37', iid='568', r_ui=3.0, est=3.7859158905641315, details={'was_impossible': False}),
#  Prediction(uid='881', iid='476', r_ui=2.0, est=2.9299257126905527, details={'was_impossible': False}),
#  Prediction(uid='320', iid='751', r_ui=4.0, est=3.881844943736104, details={'was_impossible': False}),
#  Prediction(uid='414', iid='340', r_ui=4.0, est=4.141540007448716, details={'was_impossible': False}),
#  Prediction(uid='170', iid='988', r_ui=3.0, est=2.996171556855046, details={'was_impossible': False}),
#  Prediction(uid='538', iid='173', r_ui=3.0, est=3.858229833127358, details={'was_impossible': False}),
#  Prediction(uid='829', iid='13', r_ui=4.0, est=3.3143209902980777, details={'was_impossible': False}),
#  Prediction(uid='581', iid='221', r_ui=2.0, est=3.95502912235161, details={'was_impossible': False}),
#  Prediction(uid='644', iid='289', r_ui=1.0, est=4.017356529843077, details={'was_impossible': False}),
#  Prediction(uid='178', iid='881', r_ui=2.0, est=2.9079998106681417, details={'was_impossible': False}),
#  Prediction(uid='450', iid='80', r_ui=3.0, est=3.2043985548926956, details={'was_impossible': False}),
#  Prediction(uid='303', iid='779', r_ui=1.0, est=2.8197543214935847, details={'was_impossible': False}),
#  Prediction(uid='370', iid='195', r_ui=4.0, est=3.4949172654612606, details={'was_impossible': False}),
#  Prediction(uid='296', iid='462', r_ui=4.0, est=4.408915092636743, details={'was_impossible': False}),
#  Prediction(uid='763', iid='222', r_ui=5.0, est=3.636745708907398, details={'was_impossible': False}),
#  Prediction(uid='69', iid='100', r_ui=5.0, est=4.450827312711232, details={'was_impossible': False}),
#  Prediction(uid='389', iid='1168', r_ui=3.0, est=3.653841241259767, details={'was_impossible': False}),
#  Prediction(uid='44', iid='448', r_ui=2.0, est=3.417693207369153, details={'was_impossible': False}),
# ...
#  Prediction(uid='592', iid='1017', r_ui=4.0, est=3.7596004864288814, details={'was_impossible': False}),
#  Prediction(uid='385', iid='93', r_ui=3.0, est=4.069762804759583, details={'was_impossible': False}),
#  Prediction(uid='687', iid='321', r_ui=4.0, est=3.245935029083879, details={'was_impossible': False}),
#  Prediction(uid='505', iid='423', r_ui=4.0, est=3.345135042328115, details={'was_impossible': False}),
#  Prediction(uid='537', iid='209', r_ui=4.0, est=3.50046362462772, details={'was_impossible': False}),
#  Prediction(uid='374', iid='25', r_ui=5.0, est=3.2977358344452763, details={'was_impossible': False}),
#  Prediction(uid='393', iid='338', r_ui=2.0, est=2.8070131997299397, details={'was_impossible': False}),
#  Prediction(uid='506', iid='892', r_ui=1.0, est=2.7258436816338834, details={'was_impossible': False}),
#  Prediction(uid='903', iid='98', r_ui=5.0, est=4.345343963507585, details={'was_impossible': False}),
#  Prediction(uid='145', iid='574', r_ui=2.0, est=2.8116240514688897, details={'was_impossible': False}),
#  Prediction(uid='194', iid='188', r_ui=4.0, est=3.4269845013190645, details={'was_impossible': False}),
#  Prediction(uid='458', iid='1070', r_ui=4.0, est=3.651791866066614, details={'was_impossible': False}),
#  Prediction(uid='25', iid='269', r_ui=4.0, est=4.446591710481131, details={'was_impossible': False}),
#  Prediction(uid='790', iid='232', r_ui=4.0, est=3.2804985221198346, details={'was_impossible': False}),
#  Prediction(uid='488', iid='751', r_ui=3.0, est=3.1160967726300597, details={'was_impossible': False}),
#  Prediction(uid='713', iid='539', r_ui=3.0, est=2.1113415315461563, details={'was_impossible': False}),
#  Prediction(uid='561', iid='739', r_ui=2.0, est=1.954631548611565, details={'was_impossible': False}),
#  Prediction(uid='500', iid='1160', r_ui=5.0, est=3.0055466955261747, details={'was_impossible': False}),
#  Prediction(uid='407', iid='715', r_ui=4.0, est=3.210974973465035, details={'was_impossible': False}),
#  Prediction(uid='498', iid='144', r_ui=1.0, est=3.5072495709048312, details={'was_impossible': False}),
#  Prediction(uid='655', iid='640', r_ui=2.0, est=2.2893388423626324, details={'was_impossible': False}),
#  Prediction(uid='663', iid='173', r_ui=3.0, est=4.081934922861795, details={'was_impossible': False}),
#  Prediction(uid='385', iid='168', r_ui=3.0, est=3.641334865526814, details={'was_impossible': False}),
#  Prediction(uid='551', iid='1087', r_ui=1.0, est=3.3189687405839825, details={'was_impossible': False}),
#  Prediction(uid='864', iid='167', r_ui=4.0, est=3.260959820253848, details={'was_impossible': False}),
#  Prediction(uid='648', iid='185', r_ui=5.0, est=4.150864820910347, details={'was_impossible': False}),
#  Prediction(uid='91', iid='529', r_ui=4.0, est=4.034838469873998, details={'was_impossible': False}),
#  Prediction(uid='576', iid='319', r_ui=3.0, est=2.99150243389263, details={'was_impossible': False}),
#  Prediction(uid='457', iid='450', r_ui=4.0, est=3.0536229855599686, details={'was_impossible': False}),
#  Prediction(uid='716', iid='502', r_ui=3.0, est=3.804134534949406, details={'was_impossible': False}),
#  Prediction(uid='343', iid='65', r_ui=5.0, est=3.770092449447863, details={'was_impossible': False}),
#  Prediction(uid='862', iid='919', r_ui=4.0, est=4.235665017283014, details={'was_impossible': False}),
#  Prediction(uid='406', iid='52', r_ui=5.0, est=3.9929856176510192, details={'was_impossible': False}),
#  Prediction(uid='846', iid='662', r_ui=3.0, est=3.6140267130842783, details={'was_impossible': False}),
#  Prediction(uid='707', iid='676', r_ui=4.0, est=3.314449137137519, details={'was_impossible': False}),
#  Prediction(uid='589', iid='286', r_ui=3.0, est=3.4131831647555746, details={'was_impossible': False}),
#  Prediction(uid='139', iid='1233', r_ui=5.0, est=3.5569409073512905, details={'was_impossible': False}),
#  Prediction(uid='354', iid='32', r_ui=3.0, est=3.916854040176386, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1043', r_ui=3.0, est=3.2471744182260203, details={'was_impossible': False}),
#  Prediction(uid='566', iid='483', r_ui=4.0, est=4.505200901886135, details={'was_impossible': False}),
#  Prediction(uid='188', iid='553', r_ui=4.0, est=3.2436222116452127, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1311', r_ui=3.0, est=2.2743976060657656, details={'was_impossible': False}),
#  Prediction(uid='787', iid='681', r_ui=3.0, est=2.465867456857936, details={'was_impossible': False}),
#  Prediction(uid='99', iid='815', r_ui=2.0, est=3.4762641410958253, details={'was_impossible': False}),
#  Prediction(uid='101', iid='742', r_ui=4.0, est=3.3525628497300555, details={'was_impossible': False}),
#  Prediction(uid='72', iid='197', r_ui=5.0, est=4.15529742552069, details={'was_impossible': False}),
#  Prediction(uid='774', iid='215', r_ui=3.0, est=1.9730680949149408, details={'was_impossible': False}),
#  Prediction(uid='279', iid='547', r_ui=1.0, est=4.170511430058567, details={'was_impossible': False}),
#  Prediction(uid='234', iid='259', r_ui=2.0, est=2.690800268752389, details={'was_impossible': False}),
#  Prediction(uid='210', iid='195', r_ui=4.0, est=4.208333553586449, details={'was_impossible': False}),
#  Prediction(uid='240', iid='242', r_ui=5.0, est=4.4551534734534535, details={'was_impossible': False}),
#  Prediction(uid='916', iid='17', r_ui=4.0, est=3.0171205156685907, details={'was_impossible': False}),
#  Prediction(uid='643', iid='168', r_ui=5.0, est=4.203358580995415, details={'was_impossible': False}),
#  Prediction(uid='492', iid='192', r_ui=3.0, est=3.6622141947231013, details={'was_impossible': False}),
#  Prediction(uid='303', iid='293', r_ui=4.0, est=4.022722202356953, details={'was_impossible': False}),
#  Prediction(uid='387', iid='295', r_ui=3.0, est=2.9973035661514182, details={'was_impossible': False}),
#  Prediction(uid='722', iid='148', r_ui=3.0, est=3.6447821896025014, details={'was_impossible': False}),
#  Prediction(uid='638', iid='161', r_ui=4.0, est=3.2797932678993615, details={'was_impossible': False}),
#  Prediction(uid='3', iid='348', r_ui=4.0, est=2.8966233505467005, details={'was_impossible': False}),
#  Prediction(uid='927', iid='403', r_ui=4.0, est=3.9137656942784944, details={'was_impossible': False}),
#  Prediction(uid='882', iid='1052', r_ui=2.0, est=3.1660853315145316, details={'was_impossible': False}),
#  Prediction(uid='628', iid='301', r_ui=4.0, est=4.114050892063012, details={'was_impossible': False}),
#  Prediction(uid='1', iid='236', r_ui=4.0, est=3.798284474058267, details={'was_impossible': False}),
#  Prediction(uid='374', iid='685', r_ui=4.0, est=3.7035284153686963, details={'was_impossible': False}),
#  Prediction(uid='634', iid='544', r_ui=3.0, est=3.19172049447116, details={'was_impossible': False}),
#  Prediction(uid='54', iid='406', r_ui=2.0, est=2.8256382099245627, details={'was_impossible': False}),
#  Prediction(uid='268', iid='73', r_ui=3.0, est=2.701799384044501, details={'was_impossible': False}),
#  Prediction(uid='434', iid='546', r_ui=5.0, est=3.721165934646761, details={'was_impossible': False}),
#  Prediction(uid='833', iid='181', r_ui=2.0, est=3.1619379184408567, details={'was_impossible': False}),
#  Prediction(uid='768', iid='222', r_ui=4.0, est=3.5368163084306015, details={'was_impossible': False}),
#  Prediction(uid='437', iid='401', r_ui=5.0, est=2.7584742444775245, details={'was_impossible': False}),
#  Prediction(uid='222', iid='472', r_ui=2.0, est=2.9174256279653568, details={'was_impossible': False}),
#  Prediction(uid='79', iid='116', r_ui=5.0, est=3.9165936028349746, details={'was_impossible': False}),
#  Prediction(uid='270', iid='1148', r_ui=5.0, est=4.312705976401633, details={'was_impossible': False}),
#  Prediction(uid='894', iid='1255', r_ui=4.0, est=2.8322780601623756, details={'was_impossible': False}),
#  Prediction(uid='1', iid='111', r_ui=5.0, est=3.7549111643719937, details={'was_impossible': False}),
#  Prediction(uid='18', iid='197', r_ui=4.0, est=4.347738056910371, details={'was_impossible': False}),
#  Prediction(uid='354', iid='88', r_ui=2.0, est=3.1529048469792973, details={'was_impossible': False}),
#  Prediction(uid='345', iid='79', r_ui=4.0, est=3.8658198003215314, details={'was_impossible': False}),
#  Prediction(uid='305', iid='770', r_ui=3.0, est=3.213523628538453, details={'was_impossible': False}),
#  Prediction(uid='301', iid='53', r_ui=1.0, est=3.139832726411916, details={'was_impossible': False}),
#  Prediction(uid='207', iid='56', r_ui=4.0, est=3.5716154756877443, details={'was_impossible': False}),
#  Prediction(uid='933', iid='449', r_ui=1.0, est=2.2856020276872435, details={'was_impossible': False}),
#  Prediction(uid='251', iid='64', r_ui=5.0, est=4.503541261009222, details={'was_impossible': False}),
#  Prediction(uid='263', iid='483', r_ui=5.0, est=4.751157562093996, details={'was_impossible': False}),
#  Prediction(uid='500', iid='1163', r_ui=1.0, est=2.774293872347668, details={'was_impossible': False}),
#  Prediction(uid='435', iid='616', r_ui=2.0, est=3.5201883405387213, details={'was_impossible': False}),
#  Prediction(uid='558', iid='116', r_ui=5.0, est=4.192442224473585, details={'was_impossible': False}),
#  Prediction(uid='896', iid='219', r_ui=3.0, est=3.194194504483336, details={'was_impossible': False}),
#  Prediction(uid='583', iid='268', r_ui=5.0, est=3.9408446809660784, details={'was_impossible': False}),
#  Prediction(uid='465', iid='705', r_ui=4.0, est=3.634120442599845, details={'was_impossible': False}),
#  Prediction(uid='747', iid='1225', r_ui=3.0, est=3.2952009921362695, details={'was_impossible': False}),
#  Prediction(uid='84', iid='591', r_ui=4.0, est=4.025581298443502, details={'was_impossible': False}),
#  Prediction(uid='715', iid='265', r_ui=5.0, est=3.87771010798288, details={'was_impossible': False}),
#  Prediction(uid='650', iid='154', r_ui=3.0, est=3.435602920758276, details={'was_impossible': False}),
#  Prediction(uid='222', iid='70', r_ui=3.0, est=3.5124147609850724, details={'was_impossible': False}),
#  Prediction(uid='669', iid='208', r_ui=2.0, est=3.6798628059072698, details={'was_impossible': False}),
#  Prediction(uid='392', iid='269', r_ui=5.0, est=4.370732670448626, details={'was_impossible': False}),
#  Prediction(uid='191', iid='300', r_ui=4.0, est=3.4587109420777593, details={'was_impossible': False}),
#  Prediction(uid='268', iid='302', r_ui=5.0, est=4.1929109550216275, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1021', r_ui=4.0, est=3.8602121239686262, details={'was_impossible': False}),
#  Prediction(uid='648', iid='431', r_ui=5.0, est=3.4985843958283085, details={'was_impossible': False}),
#  Prediction(uid='181', iid='974', r_ui=4.0, est=1.6964051628859955, details={'was_impossible': False}),
#  Prediction(uid='100', iid='310', r_ui=3.0, est=3.1938320629392654, details={'was_impossible': False}),
#  Prediction(uid='942', iid='659', r_ui=5.0, est=4.384831743822509, details={'was_impossible': False}),
#  Prediction(uid='299', iid='73', r_ui=2.0, est=3.2800792371752467, details={'was_impossible': False}),
#  Prediction(uid='324', iid='339', r_ui=3.0, est=4.339203951624196, details={'was_impossible': False}),
#  Prediction(uid='943', iid='367', r_ui=4.0, est=3.834270249166828, details={'was_impossible': False}),
#  Prediction(uid='131', iid='221', r_ui=3.0, est=4.088997899478206, details={'was_impossible': False}),
#  Prediction(uid='73', iid='475', r_ui=4.0, est=3.972303599283704, details={'was_impossible': False}),
#  Prediction(uid='361', iid='97', r_ui=4.0, est=3.5881830616616743, details={'was_impossible': False}),
#  Prediction(uid='48', iid='427', r_ui=4.0, est=4.310267981873427, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1016', r_ui=3.0, est=3.2071001386276308, details={'was_impossible': False}),
#  Prediction(uid='744', iid='340', r_ui=3.0, est=3.6571994940870494, details={'was_impossible': False}),
#  Prediction(uid='487', iid='3', r_ui=5.0, est=2.8081695748307, details={'was_impossible': False}),
#  Prediction(uid='271', iid='750', r_ui=4.0, est=3.808298883623444, details={'was_impossible': False}),
#  Prediction(uid='58', iid='127', r_ui=4.0, est=4.041895105645567, details={'was_impossible': False}),
#  Prediction(uid='66', iid='24', r_ui=3.0, est=3.5928490842360854, details={'was_impossible': False}),
#  Prediction(uid='504', iid='357', r_ui=4.0, est=4.502048142315415, details={'was_impossible': False}),
#  Prediction(uid='711', iid='288', r_ui=1.0, est=3.328925674744226, details={'was_impossible': False}),
#  Prediction(uid='264', iid='269', r_ui=5.0, est=4.317705305262276, details={'was_impossible': False}),
#  Prediction(uid='145', iid='59', r_ui=1.0, est=4.037971834791098, details={'was_impossible': False}),
#  Prediction(uid='579', iid='179', r_ui=3.0, est=3.4175186047422117, details={'was_impossible': False}),
#  Prediction(uid='11', iid='216', r_ui=3.0, est=3.7479671129184187, details={'was_impossible': False}),
#  Prediction(uid='453', iid='79', r_ui=3.0, est=3.771633137341302, details={'was_impossible': False}),
#  Prediction(uid='276', iid='29', r_ui=3.0, est=2.8715638356937476, details={'was_impossible': False}),
#  Prediction(uid='707', iid='863', r_ui=4.0, est=3.4123706883416696, details={'was_impossible': False}),
#  Prediction(uid='742', iid='181', r_ui=3.0, est=4.070600440742428, details={'was_impossible': False}),
#  Prediction(uid='598', iid='243', r_ui=2.0, est=2.5353357192055093, details={'was_impossible': False}),
#  Prediction(uid='776', iid='569', r_ui=3.0, est=2.5855996810384063, details={'was_impossible': False}),
#  Prediction(uid='815', iid='86', r_ui=5.0, est=4.06798155592287, details={'was_impossible': False}),
#  Prediction(uid='922', iid='68', r_ui=4.0, est=3.366024833207221, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1291', r_ui=2.0, est=2.5740604467259787, details={'was_impossible': False}),
#  Prediction(uid='104', iid='544', r_ui=3.0, est=2.4809953659283375, details={'was_impossible': False}),
#  Prediction(uid='804', iid='434', r_ui=4.0, est=4.115352215331494, details={'was_impossible': False}),
#  Prediction(uid='336', iid='746', r_ui=3.0, est=3.8213884558276314, details={'was_impossible': False}),
#  Prediction(uid='378', iid='393', r_ui=3.0, est=3.159015671014601, details={'was_impossible': False}),
#  Prediction(uid='497', iid='1', r_ui=4.0, est=3.6616643540146336, details={'was_impossible': False}),
#  Prediction(uid='493', iid='69', r_ui=5.0, est=3.989355997904282, details={'was_impossible': False}),
#  Prediction(uid='453', iid='717', r_ui=2.0, est=2.53774611751997, details={'was_impossible': False}),
#  Prediction(uid='399', iid='578', r_ui=2.0, est=2.8092018991953682, details={'was_impossible': False}),
#  Prediction(uid='342', iid='1128', r_ui=5.0, est=2.7496766108895576, details={'was_impossible': False}),
#  Prediction(uid='537', iid='239', r_ui=2.0, est=2.2499763801887487, details={'was_impossible': False}),
#  Prediction(uid='553', iid='435', r_ui=4.0, est=4.0936993449147066, details={'was_impossible': False}),
#  Prediction(uid='376', iid='223', r_ui=4.0, est=4.201211199322193, details={'was_impossible': False}),
#  Prediction(uid='606', iid='237', r_ui=4.0, est=3.653918227133904, details={'was_impossible': False}),
#  Prediction(uid='451', iid='337', r_ui=2.0, est=2.7655604268094933, details={'was_impossible': False}),
#  Prediction(uid='593', iid='238', r_ui=4.0, est=3.8594245533203626, details={'was_impossible': False}),
#  Prediction(uid='280', iid='748', r_ui=2.0, est=3.2999380914119087, details={'was_impossible': False}),
#  Prediction(uid='916', iid='512', r_ui=5.0, est=3.7891748535020158, details={'was_impossible': False}),
#  Prediction(uid='889', iid='678', r_ui=3.0, est=2.3239663984391625, details={'was_impossible': False}),
#  Prediction(uid='555', iid='195', r_ui=4.0, est=4.219032572089565, details={'was_impossible': False}),
#  Prediction(uid='323', iid='1017', r_ui=3.0, est=3.607513912411479, details={'was_impossible': False}),
#  Prediction(uid='716', iid='195', r_ui=1.0, est=3.441789546385637, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# ### 4.4 Evaluation

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9422
# 0.9422377857356765

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7425
# 0.7424685450783365

# %% [markdown]
# ### 4.5 Cross Validation

# %%
cross_validate(model_SVD, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9383  0.9361  0.9381  0.9341  0.9418  0.9377  0.0025
# MAE (testset)     0.7394  0.7375  0.7400  0.7356  0.7395  0.7384  0.0016
# Fit time          4.07    4.05    4.03    4.05    4.06    4.05    0.01
# Test time         0.12    0.18    0.12    0.18    0.12    0.14    0.03
# {'fit_time': (4.071376800537109,
#   4.0538084506988525,
#   4.030364751815796,
#   4.046112537384033,
#   4.056187868118286),
#  'test_mae': array([0.7394473 , 0.73747447, 0.74001503, 0.73559976, 0.73948018]),
#  'test_rmse': array([0.93825299, 0.93605329, 0.93809253, 0.93413806, 0.94178145]),
#  'test_time': (0.11727261543273926,
#   0.18349361419677734,
#   0.1197512149810791,
#   0.17941570281982422,
#   0.11533975601196289)}

# %% [markdown]
# # Use of Pipeline and build two models

# %% [markdown]
# ## 5 Using KNNwithMeans algorithm

# %% [markdown]
# #### 5.1 Check best score and best params to build models

# %%
from surprise import KNNWithMeans
# from surprise import Dataset
from surprise.model_selection import GridSearchCV

# data = Dataset.load_builtin("ml-100k")
sim_options = {
    "name": ["msd", "cosine"],
    "min_support": [3, 4, 5],
    "user_based": [False, True],
}
param_grid = {"sim_options": sim_options}

gs = GridSearchCV(KNNWithMeans, param_grid, measures=["rmse", "mae"], cv=3)
gs.fit(data)

print(gs.best_score["rmse"])
print(gs.best_params["rmse"])
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 0.942754091834315
# {'sim_options': {'name': 'msd', 'min_support': 3, 'user_based': False}}

# %% [markdown]
# #### 5.2 Build Model

# %%
# Using best params from above data
sim_options = {
    "name": "msd",
    "user_based": False,  # Compute  similarities between items
}
model_KNNWithMeans = KNNWithMeans(sim_options=sim_options)
model_KNNWithMeans.fit(train)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ### 5.3 Prediction

# %%
pred_KNNWithMeans = model_KNNWithMeans.test(test)

# %%
pred_KNNWithMeans
# Out:
# [Prediction(uid='391', iid='591', r_ui=4.0, est=3.4081618213595783, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='1291', r_ui=1.0, est=1.6957735725954333, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='637', iid='268', r_ui=2.0, est=2.9879049464497935, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='332', iid='451', r_ui=5.0, est=4.113439566471616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='204', r_ui=4.0, est=3.8430048887370565, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='27', iid='286', r_ui=3.0, est=3.527979423991914, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='387', iid='663', r_ui=4.0, est=3.8230888217722683, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='722', r_ui=3.0, est=2.5644448440139858, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='820', iid='347', r_ui=4.0, est=3.0509050164425116, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='820', iid='358', r_ui=1.0, est=2.1787555085302968, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='911', iid='709', r_ui=5.0, est=4.181205204513128, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='892', iid='71', r_ui=3.0, est=4.426228679621172, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='524', iid='321', r_ui=3.0, est=3.0305146051677974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='887', iid='1278', r_ui=2.0, est=4.28291012573649, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='839', iid='1664', r_ui=1.0, est=3.6071126261453372, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='608', iid='58', r_ui=2.0, est=3.8783169200902146, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='14', r_ui=2.0, est=4.033444775318648, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='709', iid='183', r_ui=5.0, est=3.8779683717545725, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='862', iid='405', r_ui=2.0, est=4.122200767203978, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='654', iid='785', r_ui=4.0, est=3.3444513336281423, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='218', iid='294', r_ui=2.0, est=2.9039048567798296, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='655', iid='1211', r_ui=4.0, est=2.7784300676086033, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='606', iid='763', r_ui=5.0, est=3.9506034876595413, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='326', iid='837', r_ui=4.0, est=3.7243988463369195, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='24', iid='372', r_ui=4.0, est=4.274184889620683, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='306', iid='864', r_ui=3.0, est=3.2484060869460314, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='234', iid='663', r_ui=4.0, est=3.4030254191928346, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='669', iid='522', r_ui=4.0, est=3.346892512275631, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='385', iid='657', r_ui=4.0, est=4.342492932161386, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='782', iid='1644', r_ui=2.0, est=3.53064, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='663', iid='187', r_ui=5.0, est=4.267052642098041, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='178', iid='111', r_ui=4.0, est=3.8995798869481595, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='164', iid='370', r_ui=5.0, est=3.440208009040088, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='326', r_ui=4.0, est=3.0312664521392514, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='634', iid='471', r_ui=4.0, est=3.6061312283426123, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='705', iid='89', r_ui=2.0, est=4.116949653694866, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='348', iid='974', r_ui=4.0, est=3.8054452844348794, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='622', iid='31', r_ui=3.0, est=3.6213753692866764, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='201', r_ui=5.0, est=3.7040419552800175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='363', iid='95', r_ui=3.0, est=3.2952214826254007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='320', r_ui=5.0, est=2.4022341139653136, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='559', iid='502', r_ui=4.0, est=3.3686975515899773, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='43', r_ui=1.0, est=2.9613734607880144, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='457', iid='194', r_ui=5.0, est=4.689496128287576, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='538', iid='121', r_ui=3.0, est=3.24613467651211, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='582', iid='455', r_ui=1.0, est=3.067797406754797, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='774', iid='2', r_ui=1.0, est=1.7754195089955542, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='773', iid='70', r_ui=3.0, est=3.4170590679956083, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='67', iid='7', r_ui=5.0, est=4.3505882511156475, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='151', iid='1098', r_ui=1.0, est=4.246019068902404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='496', iid='333', r_ui=3.0, est=3.0665438559639293, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='774', iid='230', r_ui=2.0, est=2.327439591048876, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='214', iid='340', r_ui=3.0, est=3.796936201973534, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='901', iid='321', r_ui=1.0, est=3.6174041247470194, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='293', iid='789', r_ui=2.0, est=3.3512325266524905, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='72', iid='127', r_ui=5.0, est=4.243686843006951, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18', iid='462', r_ui=3.0, est=3.8024568884518857, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='90', iid='496', r_ui=4.0, est=4.560229205156831, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='682', iid='628', r_ui=4.0, est=3.1644874549130146, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='262', iid='778', r_ui=4.0, est=3.323415098980113, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='933', iid='230', r_ui=3.0, est=2.5936841066399405, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='322', r_ui=3.0, est=3.1613021575870817, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='690', iid='216', r_ui=4.0, est=3.6580772805578805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='650', iid='82', r_ui=3.0, est=3.45257520506603, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid
details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='253', iid='220', r_ui=4.0, est=3.5127137852905785, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='210', r_ui=5.0, est=4.061987411171672, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='714', iid='1152', r_ui=2.0, est=3.773162185893522, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='505', iid='724', r_ui=4.0, est=3.2056414659059045, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='343', iid='26', r_ui=3.0, est=3.7784188364437394, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='234', iid='197', r_ui=5.0, est=3.570251399650984, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='485', iid='346', r_ui=4.0, est=3.3230653048296848, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='125', iid='174', r_ui=5.0, est=4.286081940748327, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='344', iid='472', r_ui=3.0, est=2.7445618769285884, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='125', iid='87', r_ui=5.0, est=4.033787665156057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='297', iid='129', r_ui=4.0, est=3.430265236259148, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='268', r_ui=3.0, est=3.0525604972758433, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='235', r_ui=3.0, est=2.651719535833184, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='294', iid='222', r_ui=4.0, est=3.6638781960346205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='312', iid='495', r_ui=4.0, est=4.2393496276657645, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='503', iid='47', r_ui=5.0, est=3.7589689872476977, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='276', r_ui=5.0, est=3.5658924055441, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='249', r_ui=3.0, est=3.2639351658760685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16', iid='480', r_ui=5.0, est=4.906433322276983, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='328', iid='28', r_ui=5.0, est=3.9963982261120616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='204', r_ui=3.0, est=3.0643731718996574, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='327', iid='652', r_ui=4.0, est=3.5039458027918737, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='682', iid='790', r_ui=3.0, est=2.4644106150271265, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='620', iid='288', r_ui=4.0, est=3.8024624297325964, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='187', iid='197', r_ui=4.0, est=4.172117994839201, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='52', iid='1086', r_ui=4.0, est=3.763812613485257, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='126', r_ui=3.0, est=4.430028687545805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='312', r_ui=2.0, est=2.810894014024945, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='76', iid='100', r_ui=5.0, est=4.247233165495853, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='862', iid='216', r_ui=5.0, est=4.496861071123423, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='293', r_ui=4.0, est=3.74380258506742, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='387', iid='380', r_ui=2.0, est=2.9833773133142314, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='644', iid='250', r_ui=4.0, est=4.238643158354174, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='501', iid='597', r_ui=3.0, est=3.421287815366092, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='892', iid='79', r_ui=5.0, est=4.570988397013538, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='794', r_ui=5.0, est=3.9971292494430486, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='840', iid='203', r_ui=5.0, est=4.075711352940436, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='619', iid='27', r_ui=4.0, est=3.075062882373902, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='940', iid='213', r_ui=4.0, est=3.67719740278889, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='760', iid='375', r_ui=4.0, est=1.7179711413044498, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='642', iid='69', r_ui=5.0, est=4.037975737242015, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='432', iid='151', r_ui=4.0, est=3.9255628051017273, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='535', r_ui=3.0, est=3.6522049762271527, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='254', iid='610', r_ui=2.0, est=3.309414929088894, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1', iid='18', r_ui=4.0, est=3.1523224972329222, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='6', r_ui=4.0, est=3.0678205315390494, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='932', iid='513', r_ui=5.0, est=4.765813828489489, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='702', iid='1127', r_ui=2.0, est=1.7315164414469768, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='407', iid='208', r_ui=4.0, est=3.8578421462285872, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='292', iid='631', r_ui=5.0, est=3.952978545024046, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='474', iid='196', r_ui=5.0, est=4.036975326201495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='436', iid='649', r_ui=5.0, est=3.3607786706765497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='859', iid='846', r_ui=5.0, est=3.478719408762195, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='248', iid='294', r_ui=3.0, est=2.8611103878644575, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='907', iid='405', r_ui=4.0, est=4.681619820290764, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='577', iid='22', r_ui=5.0, est=4.561416366053353, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='437', iid='401', r_ui=5.0, est=2.5723104836110404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='472', r_ui=2.0, est=2.938847585062606, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='79', iid='116', r_ui=5.0, est=3.887144059408613, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='270', iid='1148', r_ui=5.0, est=4.086393072821616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='1255', r_ui=4.0, est=2.247516329468328, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1', iid='111', r_ui=5.0, est=3.605548053159988, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18', iid='197', r_ui=4.0, est=4.08161936531962, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='354', iid='88', r_ui=2.0, est=3.438301257121759, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='345', iid='79', r_ui=4.0, est=4.249404223032763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='305', iid='770', r_ui=3.0, est=3.236210776941535, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='301', iid='53', r_ui=1.0, est=3.1105349625293703, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='207', iid='56', r_ui=4.0, est=3.723430936857904, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='933', iid='449', r_ui=1.0, est=1.9985953963123682, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='251', iid='64', r_ui=5.0, est=4.674685873594816, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='263', iid='483', r_ui=5.0, est=4.798234639972218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='500', iid='1163', r_ui=1.0, est=2.8241100626765245, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='435', iid='616', r_ui=2.0, est=3.4899049808047873, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='558', iid='116', r_ui=5.0, est=4.068858528496496, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='896', iid='219', r_ui=3.0, est=2.6712402164965887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='583', iid='268', r_ui=5.0, est=4.279177172966226, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='465', iid='705', r_ui=4.0, est=3.4115617714860846, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='747', iid='1225', r_ui=3.0, est=2.7549022148854867, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='84', iid='591', r_ui=4.0, est=3.8692474491932316, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='715', iid='265', r_ui=5.0, est=4.020526800381327, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='650', iid='154', r_ui=3.0, est=3.336796091432483, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='70', r_ui=3.0, est=3.689127117574077, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='669', iid='208', r_ui=2.0, est=3.840162406424988, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='392', iid='269', r_ui=5.0, est=4.449116679579206, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='191', iid='300', r_ui=4.0, est=3.6058094644257537, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='268', iid='302', r_ui=5.0, est=4.1298220513749495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='409', iid='1021', r_ui=4.0, est=3.670946189021672, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='431', r_ui=5.0, est=3.5911485269532237, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='974', r_ui=4.0, est=1.4885977854764598, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='100', iid='310', r_ui=3.0, est=3.3036309573128237, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='942', iid='659', r_ui=5.0, est=4.422671491783321, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='299', iid='73', r_ui=2.0, est=3.239726694622898, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='324', iid='339', r_ui=3.0, est=4.293296050024013, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='943', iid='367', r_ui=4.0, est=3.51620027598646, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='131', iid='221', r_ui=3.0, est=4.256899498650079, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='73', iid='475', r_ui=4.0, est=4.026633330513111, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='361', iid='97', r_ui=4.0, est=3.6633725867057447, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48', iid='427', r_ui=4.0, est=4.338558421507936, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='1016', r_ui=3.0, est=3.2019076608846255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='744', iid='340', r_ui=3.0, est=3.4206883230431413, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='487', iid='3', r_ui=5.0, est=3.207581208366174, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='750', r_ui=4.0, est=3.8169806886855233, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='58', iid='127', r_ui=4.0, est=4.404510775744603, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='66', iid='24', r_ui=3.0, est=3.643974210763319, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='504', iid='357', r_ui=4.0, est=4.242768714905774, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='711', iid='288', r_ui=1.0, est=3.4988297261961643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='264', iid='269', r_ui=5.0, est=4.611166859072735, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='59', r_ui=1.0, est=3.9428471474469804, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='579', iid='179', r_ui=3.0, est=3.780307567133018, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11', iid='216', r_ui=3.0, est=3.8036382493690724, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='453', iid='79', r_ui=3.0, est=3.9469438776953476, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='29', r_ui=3.0, est=2.5637079196507027, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='863', r_ui=4.0, est=3.773129724537384, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='742', iid='181', r_ui=3.0, est=3.917832731013492, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='598', iid='243', r_ui=2.0, est=2.3619733499996207, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='776', iid='569', r_ui=3.0, est=2.577189665289605, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='815', iid='86', r_ui=5.0, est=4.300181594436744, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='922', iid='68', r_ui=4.0, est=3.315807315786637, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='1291', r_ui=2.0, est=2.6711892383913867, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='104', iid='544', r_ui=3.0, est=2.1610427494174242, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='434', r_ui=4.0, est=4.174405545030052, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='336', iid='746', r_ui=3.0, est=3.7986086834829242, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='378', iid='393', r_ui=3.0, est=3.216218094266163, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='497', iid='1', r_ui=4.0, est=3.485947277113257, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='493', iid='69', r_ui=5.0, est=4.007202577788974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='453', iid='717', r_ui=2.0, est=2.5522265338653582, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='578', r_ui=2.0, est=3.1342628106026598, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='1128', r_ui=5.0, est=1.9599987143079451, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='239', r_ui=2.0, est=2.7937603460125056, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='553', iid='435', r_ui=4.0, est=4.1960560899529025, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='376', iid='223', r_ui=4.0, est=4.2308604488102795, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='606', iid='237', r_ui=4.0, est=3.874763280037275, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='451', iid='337', r_ui=2.0, est=2.592554765527821, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='238', r_ui=4.0, est=3.9464201798412115, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='748', r_ui=2.0, est=3.7693295040275303, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='512', r_ui=5.0, est=3.826855019260914, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='678', r_ui=3.0, est=2.500794721149518, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='555', iid='195', r_ui=4.0, est=4.255652286973789, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='323', iid='1017', r_ui=3.0, est=3.2686803080699547, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='195', r_ui=1.0, est=3.987208297037435, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %% [markdown]
# ### 5.4 Accuracy

# %%
accuracy.rmse(pred_KNNWithMeans)
# Out:
# RMSE: 0.9377
# 0.9376561891346782

# %%
accuracy.mae(pred_KNNWithMeans)
# Out:
# MAE:  0.7355
# 0.7355240537993545

# %% [markdown]
# ### 5.5 Cross Validate

# %%
cross_validate(model_KNNWithMeans, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9342  0.9323  0.9360  0.9308  0.9386  0.9344  0.0027
# MAE (testset)     0.7340  0.7342  0.7353  0.7279  0.7365  0.7336  0.0030
# Fit time          0.39    0.40    0.45    0.40    0.40    0.41    0.02
# Test time         3.04    3.08    3.09    3.16    3.26    3.13    0.08
# {'fit_time': (0.39069151878356934,
#   0.4045116901397705,
#   0.4527461528778076,
#   0.3969156742095947,
#   0.40216946601867676),
#  'test_mae': array([0.73395681, 0.73416171, 0.73527573, 0.72792687, 0.73649539]),
#  'test_rmse': array([0.93415215, 0.93232342, 0.93599398, 0.93076482, 0.93858647]),
#  'test_time': (3.0405125617980957,
#   3.0809500217437744,
#   3.0906777381896973,
#   3.163834810256958,
#   3.264052629470825)}

# %% [markdown]
# ## 6 KNNBaseLine Model

# %% [markdown]
# ### 6.1 Check best score and best params to build models

# %%
from surprise import KNNBaseline
# from surprise import Dataset
from surprise.model_selection import GridSearchCV

# data = Dataset.load_builtin("ml-100k")
sim_options = {
    "name": ["msd", "pearson_baseline"],
    "min_support": [3, 4, 5],
    "user_based": [False, True],
}
param_grid = {"sim_options": sim_options}

gs = GridSearchCV(KNNBaseline, param_grid, measures=["rmse", "mae"], cv=3)
gs.fit(data)

print(gs.best_score["rmse"])
print(gs.best_params["rmse"])
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# 0.9308953659569627
# {'sim_options': {'name': 'pearson_baseline', 'min_support': 3, 'user_based': False}}

# %% [markdown]
# #### 6.2 Build Model

# %%
# Using best params from above data
sim_options = {
    "name": "pearson_baseline",
    "user_based": False,  # Compute  similarities between items
}
model_KNNBaseline = KNNBaseline(sim_options=sim_options)
model_KNNBaseline.fit(train)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# #### 6.3 Prediction

# %%
pred_KnnBaseline = model_KNNBaseline.test(test)

# %%
pred_KnnBaseline
# Out:
# [Prediction(uid='391', iid='591', r_ui=4.0, est=3.4911051665539237, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='1291', r_ui=1.0, est=1.9867724998882346, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='637', iid='268', r_ui=2.0, est=2.496550303571375, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='332', iid='451', r_ui=5.0, est=4.096959193713625, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='204', r_ui=4.0, est=3.7886256278442043, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='27', iid='286', r_ui=3.0, est=3.802355488363607, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='387', iid='663', r_ui=4.0, est=3.837743659689841, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='722', r_ui=3.0, est=2.8117369976706046, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='820', iid='347', r_ui=4.0, est=3.47360893030865, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='479', iid='1444', r_ui=1.0, est=2.9327246448639372, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='195', r_ui=4.0, est=3.8391066213157385, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='669', iid='175', r_ui=4.0, est=3.801303597481671, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='295', iid='648', r_ui=4.0, est=4.6676950388670555, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='297', iid='174', r_ui=5.0, est=3.696645979768085, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='153', iid='678', r_ui=2.0, est=2.0058474364546184, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='924', iid='519', r_ui=4.0, est=4.046778296858227, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='324', iid='255', r_ui=4.0, est=4.482663592851331, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='503', iid='168', r_ui=5.0, est=4.164358284557001, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='917', iid='628', r_ui=5.0, est=3.3816694628965305, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='231', iid='924', r_ui=5.0, est=3.9819793388186278, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='13', iid='889', r_ui=3.0, est=3.396509130479705, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='539', iid='367', r_ui=3.0, est=4.054523619699287, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='447', iid='1142', r_ui=5.0, est=4.031059879427568, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='84', iid='486', r_ui=5.0, est=4.180860993928203, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='450', iid='63', r_ui=4.0, est=3.6584762333423857, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='250', iid='477', r_ui=3.0, est=3.394531497640086, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='523', r_ui=4.0, est=4.116229341452173, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='504', iid='629', r_ui=4.0, est=3.513947017723739, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='744', r_ui=3.0, est=4.01030619262408, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='616', r_ui=2.0, est=3.5523562645920284, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='676', iid='344', r_ui=5.0, est=3.617916274294285, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='660', iid='405', r_ui=2.0, est=2.148615775131019, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='164', iid='328', r_ui=5.0, est=4.472475509937634, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='269', iid='771', r_ui=1.0, est=2.081522220808572, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='76', iid='851', r_ui=4.0, est=3.712095857481663, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='491', iid='129', r_ui=4.0, est=3.907361054146548, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='276', iid='96', r_ui=5.0, est=4.46321197729023, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='283', r_ui=3.0, est=3.8925843597520786, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='504', iid='310', r_ui=4.0, est=3.839906762529723, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='572', iid='222', r_ui=2.0, est=2.943098047399534, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='788', iid='195', r_ui=3.0, est=3.652929023730999, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='426', iid='1204', r_ui=4.0, est=3.460422666678041, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='290', iid='31', r_ui=4.0, est=3.2953327062083484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='597', r_ui=3.0, est=2.5221798568654004, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='287', r_ui=4.0, est=3.6479262804962036, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='366', r_ui=3.0, est=2.886390925011771, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='254', iid='501', r_ui=3.0, est=3.181303685008419, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='605', iid='121', r_ui=1.0, est=3.0920263228562157, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='693', iid='333', r_ui=3.0, est=3.00970640232197, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='455', iid='627', r_ui=3.0, est=3.1804215470570583, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='298', iid='237', r_ui=5.0, est=3.9175475601139476, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='870', iid='461', r_ui=4.0, est=3.430584530458196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='153', iid='56', r_ui=5.0, est=3.8232041107821204, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='148', iid='169', r_ui=5.0, est=4.824542730009737, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='504', iid='416', r_ui=4.0, est=3.4038964561622524, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='739', iid='69', r_ui=5.0, est=2.909697139634366, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='540', iid='111', r_ui=4.0, est=3.6532725685035867, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='374', iid='291', r_ui=3.0, est=3.875363605010243, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='686', iid='474', r_ui=5.0, est=5, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='159', iid='294', r_ui=4.0, est=3.4926970994568194, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='238', r_ui=5.0, est=4.243236021948863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='599', iid='756', r_ui=5.0, est=4.0211905159014565, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='798', iid='1425', r_ui=4.0, est=2.7581974765428114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='190', r_ui=3.0, est=4.193978824337806, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='673', iid='286', r_ui=4.0, est=3.952447226816259, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='253', iid='220', r_ui=4.0, est=3.5752043382439656, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='716', iid='210', r_ui=5.0, est=4.3466218174580264, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='714', iid='1152', r_ui=2.0, est=3.6208068078124827, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='505', iid='724', r_ui=4.0, est=3.0424633917849064, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='343', iid='26', r_ui=3.0, est=3.8882831356554513, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='234', iid='197', r_ui=5.0, est=3.6434248512055647, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='485', iid='346', r_ui=4.0, est=3.4065495173640876, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='125', iid='174', r_ui=5.0, est=4.888537133675285, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='344', iid='472', r_ui=3.0, est=2.747506321266218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='125', iid='87', r_ui=5.0, est=4.00442440301789, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='297', iid='129', r_ui=4.0, est=3.4380241207241187, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='268', r_ui=3.0, est=2.9321111627988903, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='235', r_ui=3.0, est=2.683308526044022, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='294', iid='222', r_ui=4.0, est=3.8662863208543436, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='312', iid='495', r_ui=4.0, est=4.0097990434471535, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='503', iid='47', r_ui=5.0, est=3.7822399935408724, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='276', r_ui=5.0, est=3.631098673258428, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='249', r_ui=3.0, est=3.2370846713042236, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16', iid='480', r_ui=5.0, est=4.98582135261343, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='328', iid='28', r_ui=5.0, est=4.01242510457116, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='204', r_ui=3.0, est=2.5127323567768762, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='327', iid='652', r_ui=4.0, est=3.453098034993576, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='682', iid='790', r_ui=3.0, est=2.818263691185308, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='620', iid='288', r_ui=4.0, est=3.7315900351361133, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='187', iid='197', r_ui=4.0, est=3.910867991011729, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='52', iid='1086', r_ui=4.0, est=4.025852651790784, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='7', iid='126', r_ui=3.0, est=3.926111029672922, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='312', r_ui=2.0, est=2.3385168985010556, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='76', iid='100', r_ui=5.0, est=4.366656902918545, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='862', iid='216', r_ui=5.0, est=4.582176283721371, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='293', r_ui=4.0, est=3.3763139811057203, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='387', iid='380', r_ui=2.0, est=2.78723289216748, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='644', iid='250', r_ui=4.0, est=4.027612900143337, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='501', iid='597', r_ui=3.0, est=3.3406644492701694, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='454', iid='972', r_ui=2.0, est=2.57149337046584, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='407', iid='357', r_ui=4.0, est=4.25576500236156, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='922', iid='427', r_ui=5.0, est=3.9871459208625533, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='465', iid='318', r_ui=4.0, est=3.971839578043496, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='886', iid='425', r_ui=4.0, est=3.784601202648066, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='1019', r_ui=4.0, est=4.062426393136051, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='311', iid='1119', r_ui=4.0, est=3.866849966162982, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='864', iid='288', r_ui=5.0, est=3.7575570949095374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='236', iid='181', r_ui=4.0, est=3.6203958373948892, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16', iid='657', r_ui=5.0, est=4.958908241001477, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='455', r_ui=4.0, est=4.153851902188406, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='216', iid='546', r_ui=2.0, est=3.050401664928486, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='565', iid='855', r_ui=5.0, est=4.318640709889674, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='707', iid='133', r_ui=2.0, est=3.6732307300428753, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='761', iid='205', r_ui=4.0, est=3.213768380137052, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='387', iid='919', r_ui=5.0, est=3.8308099948642322, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='460', iid='250', r_ui=2.0, est=3.098090246894367, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='660', iid='496', r_ui=3.0, est=3.2266010377827947, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='877', iid='275', r_ui=4.0, est=4.200315153256361, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='10', iid='286', r_ui=4.0, est=4.011984304472773, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='424', iid='840', r_ui=4.0, est=3.152606476828448, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='308', iid='166', r_ui=3.0, est=3.860288424831548, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='69', r_ui=5.0, est=4.303825907808811, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='699', iid='181', r_ui=3.0, est=3.580356892258709, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='474', iid='484', r_ui=5.0, est=4.541751751922919, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='296', iid='298', r_ui=1.0, est=3.995215185251486, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='379', iid='230', r_ui=4.0, est=3.7975681537661568, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='698', iid='486', r_ui=4.0, est=2.6519377053615365, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='835', iid='1045', r_ui=4.0, est=3.58190602057166, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='371', iid='180', r_ui=4.0, est=4.154304050511721, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='229', iid='245', r_ui=3.0, est=2.1452379146667164, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='338', iid='474', r_ui=4.0, est=4.513966647502976, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='168', iid='924', r_ui=2.0, est=3.724554878599923, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='21', iid='200', r_ui=5.0, est=3.8710805341137937, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='708', iid='930', r_ui=3.0, est=2.7126336924464134, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='100', r_ui=5.0, est=4.319159259182539, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='44', r_ui=4.0, est=3.489986458151148, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='758', iid='134', r_ui=5.0, est=4.723800970352802, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='191', iid='307', r_ui=3.0, est=3.490534816792886, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='268', iid='128', r_ui=3.0, est=3.331259476708352, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='815', iid='182', r_ui=3.0, est=3.8971978518895236, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='454', iid='659', r_ui=2.0, est=3.467475505598519, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='813', r_ui=5.0, est=4.2805352422642375, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='325', iid='23', r_ui=5.0, est=4.218296803257888, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='378', iid='49', r_ui=3.0, est=3.145124778640866, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='493', iid='462', r_ui=2.0, est=3.6746178938198257, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='589', r_ui=5.0, est=4.551823393154446, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='174', iid='12', r_ui=5.0, est=4.8142824928044385, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='451', iid='264', r_ui=3.0, est=2.782092659588649, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='145', iid='5', r_ui=3.0, est=3.5119090169134304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='765', iid='971', r_ui=4.0, est=4.687891247415546, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='467', iid='1142', r_ui=5.0, est=4.08148657493113, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='669', iid='354', r_ui=1.0, est=2.735785686809059, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='298', iid='172', r_ui=4.0, est=4.573011546404374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='623', iid='181', r_ui=5.0, est=3.989182918548434, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='431', r_ui=5.0, est=3.6184471633315978, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='974', r_ui=4.0, est=1.9568908288233202, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='100', iid='310', r_ui=3.0, est=3.3546152214357856, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='942', iid='659', r_ui=5.0, est=4.470151547734171, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='299', iid='73', r_ui=2.0, est=3.1287495225872815, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='324', iid='339', r_ui=3.0, est=4.19075164021288, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='943', iid='367', r_ui=4.0, est=3.57654393428801, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='131', iid='221', r_ui=3.0, est=4.0345877794279055, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='73', iid='475', r_ui=4.0, est=4.188081168992963, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='361', iid='97', r_ui=4.0, est=3.655925387671354, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48', iid='427', r_ui=4.0, est=4.445085792316194, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='222', iid='1016', r_ui=3.0, est=3.6288416120378404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='744', iid='340', r_ui=3.0, est=3.6035481022646816, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='487', iid='3', r_ui=5.0, est=3.0571190259892966, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='750', r_ui=4.0, est=4.0464089886622805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='58', iid='127', r_ui=4.0, est=4.316401964283172, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='66', iid='24', r_ui=3.0, est=3.8179254215494476, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='504', iid='357', r_ui=4.0, est=4.367341588185201, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='711', iid='288', r_ui=1.0, est=3.318739474657588, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='264', iid='269', r_ui=5.0, est=4.601881671278396, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='59', r_ui=1.0, est=4.195061986215883, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='579', iid='179', r_ui=3.0, est=3.7391300997587193, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='11', iid='216', r_ui=3.0, est=3.7873200475376003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='453', iid='79', r_ui=3.0, est=3.8747394921780867, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='29', r_ui=3.0, est=3.0384212947962745, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='863', r_ui=4.0, est=3.463123454591671, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='742', iid='181', r_ui=3.0, est=3.248609104158827, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='598', iid='243', r_ui=2.0, est=2.9702990907318894, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='776', iid='569', r_ui=3.0, est=2.5309795597898797, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='815', iid='86', r_ui=5.0, est=4.090789896803445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='922', iid='68', r_ui=4.0, est=3.2790278673703286, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='1291', r_ui=2.0, est=3.374247301111956, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='104', iid='544', r_ui=3.0, est=2.6496076130652875, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='434', r_ui=4.0, est=4.218548707253829, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='336', iid='746', r_ui=3.0, est=3.5445394831698858, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='378', iid='393', r_ui=3.0, est=3.3381054961980032, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='497', iid='1', r_ui=4.0, est=3.7002777064577828, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='493', iid='69', r_ui=5.0, est=4.174879691301022, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='453', iid='717', r_ui=2.0, est=2.8018928428184173, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='578', r_ui=2.0, est=3.0259765625225734, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='1128', r_ui=5.0, est=3.0773542400807194, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='239', r_ui=2.0, est=2.475064731253869, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='553', iid='435', r_ui=4.0, est=4.245248131977867, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='376', iid='223', r_ui=4.0, est=4.346961847558828, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='606', iid='237', r_ui=4.0, est=3.990534958919837, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='451', iid='337', r_ui=2.0, est=2.93651530698467, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='593', iid='238', r_ui=4.0, est=3.7847740408839763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='748', r_ui=2.0, est=2.9926938744255063, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='512', r_ui=5.0, est=3.9241065737067067, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='678', r_ui=3.0, est=2.5521081523219387, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='555', iid='195', r_ui=4.0, est=4.177953072968267, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='323', iid='1017', r_ui=3.0, est=3.5751192811683192, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='716', iid='195', r_ui=1.0, est=4.144527274519362, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %% [markdown]
# #### 6.4 Accuracy

# %%
accuracy.rmse(pred_KnnBaseline)
# Out:
# RMSE: 0.9238
# 0.9237660818560733

# %%
accuracy.mae(pred_KnnBaseline)
# Out:
# MAE:  0.7230
# 0.7229722085621993

# %% [markdown]
# #### 6.5 Cross Validate

# %%
cross_validate(model_KNNBaseline, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9172  0.9112  0.9237  0.9123  0.9203  0.9169  0.0047
# MAE (testset)     0.7189  0.7162  0.7228  0.7148  0.7232  0.7192  0.0034
# Fit time          1.12    1.12    1.16    1.13    1.11    1.13    0.02
# Test time         3.44    3.47    3.42    3.42    3.37    3.42    0.03
# {'fit_time': (1.122544765472412,
#   1.1162028312683105,
#   1.1645176410675049,
#   1.1258575916290283,
#   1.1126768589019775),
#  'test_mae': array([0.71889039, 0.71618161, 0.72279423, 0.71475042, 0.7232163 ]),
#  'test_rmse': array([0.91716857, 0.91119558, 0.9236505 , 0.91230033, 0.92027441]),
#  'test_time': (3.435586452484131,
#   3.473083257675171,
#   3.4206838607788086,
#   3.416865348815918,
#   3.372520923614502)}

# %% [markdown]
# ## 7 Benchmarking

# %%
import time
import datetime
import numpy as np

# classes = ['SVD', 'KNNWithMeans', 'KNNBaseline']
classes =(model_SVD, model_KNNWithMeans, model_KNNBaseline)
table = []
# cv = 5
for klass in classes:
    start = time.time()
    out = cross_validate(klass, data, ['rmse', 'mae'], cv=5, verbose=True)
    cv_time = str(datetime.timedelta(seconds=int(time.time() - start)))
    mean_rmse = '{:.3f}'.format(np.mean(out['test_rmse']))
    mean_mae = '{:.3f}'.format(np.mean(out['test_mae']))
    new_line = [klass, mean_rmse, mean_mae, cv_time]
    table.append(new_line)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9323  0.9344  0.9367  0.9359  0.9376  0.9354  0.0019
# MAE (testset)     0.7335  0.7352  0.7398  0.7379  0.7393  0.7371  0.0024
# Fit time          3.96    3.91    3.89    3.86    3.88    3.90    0.03
# Test time         0.12    0.22    0.12    0.12    0.21    0.16    0.05
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9336  0.9305  0.9313  0.9336  0.9451  0.9348  0.0053
# MAE (testset)     0.7306  0.7307  0.7308  0.7342  0.7415  0.7336  0.0042
# Fit time          0.40    0.38    0.39    0.39    0.40    0.39    0.01
# Test time         3.01    3.13    3.01    3.05    3.14    3.07    0.06
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9166  0.9192  0.9135  0.9180  0.9151  0.9165  0.0020
# MAE (testset)     0.7183  0.7212  0.7180  0.7206  0.7154  0.7187  0.0021
# Fit time          1.16    1.13    1.15    1.12    1.14    1.14    0.01
# Test time         3.48    3.49    3.40    3.36    3.52    3.45    0.06

# %%
import pandas as pd
header = ['Movielens 100K',
          'RMSE',
          'MAE',
          'Time'
          ]
movie_df = pd.DataFrame(table, columns=header, index=['SVD', 'KNNWIthMeans', 'KNNBaseline'])

# %%
movie_df.head()
# Out:
#                                                  Movielens 100K  ...     Time
# SVD           <surprise.prediction_algorithms.matrix_factori...  ...  0:00:20
# KNNWIthMeans  <surprise.prediction_algorithms.knns.KNNWithMe...  ...  0:00:17
# KNNBaseline   <surprise.prediction_algorithms.knns.KNNBaseli...  ...  0:00:23
#
# [3 rows x 4 columns]
